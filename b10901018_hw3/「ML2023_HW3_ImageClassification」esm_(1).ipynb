# %% [markdown]
# # HW3 Image Classification
# ## We strongly recommend that you run with [Kaggle](https://www.kaggle.com/t/86ca241732c04da99aca6490080bae73) for this homework
#
# If you have any questions, please contact the TAs via TA hours, NTU COOL, or email to mlta-2023-spring@googlegroups.com

# %% [markdown]
# # Check GPU Type

# %%
# !nvidia-smi
# Out:
# Fri Mar 17 08:10:41 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    25W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Get Data
# Notes: if the links are dead, you can download the data directly from Kaggle and upload it to the workspace, or you can use the Kaggle API to directly download the data into colab.

# %%
# Download Link
# Link 1 (Dropbox): https://www.dropbox.com/s/up5q1gthsz3v0dq/food-11.zip?dl=0
# Link 2 (Google Drive): https://drive.google.com/file/d/1tbGNwk1yGoCBdu4Gi_Cia7EJ9OhubYD9/view?usp=share_link
# Link 3: Kaggle Competition.
# !pip install --upgrade --no-cache-dir gdown
# (1) dropbox link
#!wget -O food11.zip https://drive.google.com/uc?id=10bL4jEDmM4z9uzGt5KoIq8HEyW6blnLy
# (2) google drive link
# !gdown --id '10bL4jEDmM4z9uzGt5KoIq8HEyW6blnLy' --output food11.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.9/dist-packages (4.4.0)
# Collecting gdown
#   Downloading gdown-4.6.4-py3-none-any.whl (14 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from gdown) (4.9.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from gdown) (3.9.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from gdown) (4.65.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.9/dist-packages (from gdown) (2.25.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->gdown) (2.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (4.0.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# Successfully installed gdown-4.6.4
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=10bL4jEDmM4z9uzGt5KoIq8HEyW6blnLy
# To: /content/food11.zip
# 100% 1.16G/1.16G [00:07<00:00, 158MB/s]

# %%
! unzip food11.zip
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: train/9_4311.jpg
#   inflating: train/9_4376.jpg
#   inflating: train/9_7584.jpg
#   inflating: train/9_9259.jpg
#   inflating: train/9_7284.jpg
#   inflating: train/9_1748.jpg
#   inflating: train/9_1630.jpg
#   inflating: train/9_3000.jpg
#   inflating: train/9_3252.jpg
#   inflating: train/9_3880.jpg
#   inflating: train/9_9687.jpg
#   inflating: train/9_7097.jpg
#   inflating: train/9_453.jpg
#   inflating: train/9_1685.jpg
#   inflating: train/9_5144.jpg
#   inflating: train/9_4010.jpg
#   inflating: train/9_8086.jpg
#   inflating: train/9_2881.jpg
#   inflating: train/9_6089.jpg
#   inflating: train/9_9497.jpg
#   inflating: train/9_3328.jpg
#   inflating: train/9_7954.jpg
#   inflating: train/9_4958.jpg
#   inflating: train/9_1319.jpg
#   inflating: train/9_3666.jpg
#   inflating: train/2_1577.jpg
#   inflating: train/2_3800.jpg
#   inflating: train/2_5799.jpg
#   inflating: train/2_3206.jpg
#   inflating: train/2_2293.jpg
#   inflating: train/2_5235.jpg
#   inflating: train/2_3421.jpg
#   inflating: train/2_4392.jpg
#   inflating: train/2_3695.jpg
#   inflating: train/7_4508.jpg
#   inflating: train/7_4455.jpg
#   inflating: train/7_2305.jpg
#   inflating: train/7_8136.jpg
#   inflating: train/7_9785.jpg
#   inflating: train/7_8590.jpg
#   inflating: train/7_4781.jpg
#   inflating: train/7_5873.jpg
#   inflating: train/7_2734.jpg
#   inflating: train/7_2731.jpg
#   inflating: train/7_9808.jpg
#   inflating: train/7_7721.jpg
#   inflating: train/7_6608.jpg
#   inflating: train/7_9174.jpg
#   inflating: train/7_8752.jpg
#   inflating: train/7_3193.jpg
#   inflating: train/7_3502.jpg
#   inflating: train/7_3226.jpg
#   inflating: train/7_101.jpg
#   inflating: train/7_3876.jpg
#   inflating: train/7_8421.jpg
#   inflating: train/7_8142.jpg
#   inflating: train/7_2401.jpg
#   inflating: train/7_9162.jpg
#   inflating: train/7_3945.jpg
#   inflating: train/7_8388.jpg
#   inflating: train/7_7027.jpg
#   inflating: train/7_9748.jpg
#   inflating: train/7_8994.jpg
#   inflating: train/7_3713.jpg
#   inflating: train/7_4633.jpg
#   inflating: train/7_4126.jpg
#   inflating: train/7_2058.jpg
#   inflating: train/7_3377.jpg
#   inflating: train/7_419.jpg
#   inflating: train/7_3154.jpg
#   inflating: train/7_9190.jpg
#   inflating: train/7_6605.jpg
#   inflating: train/7_4949.jpg
#   inflating: train/7_2197.jpg
#   inflating: train/7_4331.jpg
#   inflating: train/7_3357.jpg
#   inflating: train/7_1235.jpg
#   inflating: train/7_1158.jpg
#   inflating: train/7_1854.jpg
#   inflating: train/0_5008.jpg
#   inflating: train/0_6347.jpg
#   inflating: train/0_4765.jpg
#   inflating: train/0_8967.jpg
#   inflating: train/0_987.jpg
#   inflating: train/0_6361.jpg
#   inflating: train/0_7477.jpg
#   inflating: train/0_1595.jpg
#   inflating: train/0_2172.jpg
#   inflating: train/0_5868.jpg
#   inflating: train/0_1443.jpg
#   inflating: train/0_3896.jpg
#   inflating: train/0_9217.jpg
#   inflating: train/0_3689.jpg
#   inflating: train/0_4828.jpg
#   inflating: train/0_7129.jpg
#   inflating: train/0_8440.jpg
#   inflating: train/0_3698.jpg
#   inflating: train/0_9914.jpg
#   inflating: train/0_5251.jpg
#   inflating: train/0_4860.jpg
#   inflating: train/0_3953.jpg
#   inflating: train/0_4377.jpg
#   inflating: train/6_3055.jpg
#   inflating: train/6_7484.jpg
#   inflating: train/6_8611.jpg
#   inflating: train/6_9594.jpg
#   inflating: train/6_7890.jpg
#   inflating: train/6_6071.jpg
#   inflating: train/6_121.jpg
#   inflating: train/6_5507.jpg
#   inflating: train/6_5407.jpg
#   inflating: train/6_4811.jpg
#   inflating: train/6_9153.jpg
#   inflating: train/6_4098.jpg
#   inflating: train/6_2896.jpg
#   inflating: train/6_1605.jpg
#   inflating: train/6_1946.jpg
#   inflating: train/6_2272.jpg
#   inflating: train/6_5693.jpg
#   inflating: train/6_95.jpg
#   inflating: train/6_8747.jpg
#   inflating: train/6_8836.jpg
#   inflating: train/3_509.jpg
#   inflating: train/3_8277.jpg
#   inflating: train/3_4846.jpg
#   inflating: train/3_1714.jpg
#   inflating: train/3_2024.jpg
#   inflating: train/3_498.jpg
#   inflating: train/3_6557.jpg
#   inflating: train/3_5389.jpg
#   inflating: train/3_8830.jpg
#   inflating: train/3_6771.jpg
#   inflating: train/3_4389.jpg
#   inflating: train/3_7511.jpg
#   inflating: train/3_1061.jpg
#   inflating: train/3_7448.jpg
#   inflating: train/3_2653.jpg
#   inflating: train/3_3021.jpg
#   inflating: train/3_7233.jpg
#   inflating: train/3_612.jpg
#   inflating: train/3_6784.jpg
#   inflating: train/3_800.jpg
#   inflating: train/3_2355.jpg
#   inflating: train/3_8545.jpg
#   inflating: train/3_35.jpg
#   inflating: train/3_1657.jpg
#   inflating: train/3_8042.jpg
#   inflating: train/3_6041.jpg
#   inflating: train/3_8319.jpg
#   inflating: train/3_7320.jpg
#   inflating: train/3_8175.jpg
#   inflating: train/3_5112.jpg
#   inflating: train/3_1780.jpg
#   inflating: train/3_3866.jpg
#   inflating: train/3_7629.jpg
#   inflating: train/5_2620.jpg
#   inflating: train/5_7798.jpg
#   inflating: train/5_8464.jpg
#   inflating: train/5_7291.jpg
#   inflating: train/5_29.jpg
#   inflating: train/5_7093.jpg
#   inflating: train/5_4888.jpg
#   inflating: train/5_7645.jpg
#   inflating: train/5_6800.jpg
#   inflating: train/5_6190.jpg
#   inflating: train/5_9502.jpg
#   inflating: train/4_2127.jpg
#   inflating: train/4_4298.jpg
#   inflating: train/4_2754.jpg
#   inflating: train/4_112.jpg
#   inflating: train/4_8174.jpg
#   inflating: train/10_4149.jpg
#   inflating: train/10_635.jpg
#   inflating: train/10_4384.jpg
#   inflating: train/10_5591.jpg
#   inflating: train/10_2642.jpg
#   inflating: train/10_1838.jpg
#   inflating: train/10_9040.jpg
#   inflating: train/10_6443.jpg
#   inflating: train/10_6434.jpg
#   inflating: train/10_5667.jpg
#   inflating: train/10_295.jpg
#   inflating: train/10_4694.jpg
#   inflating: train/10_6789.jpg
#   inflating: train/10_3900.jpg
#   inflating: train/10_1565.jpg
#   inflating: train/10_3200.jpg
#   inflating: train/10_2322.jpg
#   inflating: train/10_8479.jpg
#   inflating: train/1_5674.jpg
#   inflating: train/1_3531.jpg
#   inflating: train/1_202.jpg
#   inflating: train/1_8158.jpg
#   inflating: train/1_7315.jpg
#   inflating: train/1_4100.jpg
#   inflating: train/1_7400.jpg
#   inflating: train/1_3145.jpg
#   inflating: train/1_2591.jpg
#   inflating: train/1_1351.jpg
#   inflating: train/1_9000.jpg
#   inflating: train/1_919.jpg
#   inflating: train/1_6917.jpg
#   inflating: train/1_4161.jpg
#   inflating: train/1_2098.jpg
#   inflating: train/1_9068.jpg
#   inflating: train/1_6896.jpg
#   inflating: train/1_232.jpg
#   inflating: train/1_2656.jpg
#   inflating: train/1_9366.jpg
#   inflating: train/8_4624.jpg
#   inflating: train/8_4032.jpg
#   inflating: train/8_1950.jpg
#   inflating: train/8_2387.jpg
#   inflating: train/8_5754.jpg
#   inflating: train/8_1809.jpg
#   inflating: train/8_6186.jpg
#   inflating: train/8_5825.jpg
#   inflating: train/8_8177.jpg
#   inflating: train/8_7564.jpg
#   inflating: train/8_7210.jpg
#   inflating: train/8_6019.jpg
#   inflating: train/8_3874.jpg
#   inflating: train/8_1877.jpg
#   inflating: train/9_7213.jpg
#   inflating: train/9_2380.jpg
#   inflating: train/9_8344.jpg
#   inflating: train/9_3178.jpg
#   inflating: train/9_8451.jpg
#   inflating: train/9_6452.jpg
#   inflating: train/9_2636.jpg
#   inflating: train/9_4517.jpg
#   inflating: train/9_8594.jpg
#   inflating: train/9_2230.jpg
#   inflating: train/9_4929.jpg
#   inflating: train/9_8233.jpg
#   inflating: train/9_8384.jpg
#   inflating: train/9_4451.jpg
#   inflating: train/9_4438.jpg
#   inflating: train/9_2338.jpg
#   inflating: train/9_4858.jpg
#   inflating: train/9_6271.jpg
#   inflating: train/9_8824.jpg
#   inflating: train/9_6395.jpg
#   inflating: train/9_250.jpg
#   inflating: train/9_3343.jpg
#   inflating: train/9_3798.jpg
#   inflating: train/9_8829.jpg
#   inflating: train/9_2655.jpg
#   inflating: train/9_954.jpg
#   inflating: train/9_609.jpg
#   inflating: train/9_7735.jpg
#   inflating: train/9_4225.jpg
#   inflating: train/9_7462.jpg
#   inflating: train/9_9286.jpg
#   inflating: train/9_2549.jpg
#   inflating: train/9_1981.jpg
#   inflating: train/9_9261.jpg
#   inflating: train/9_5571.jpg
#   inflating: train/9_164.jpg
#   inflating: train/9_491.jpg
#   inflating: train/9_3553.jpg
#   inflating: train/9_1398.jpg
#   inflating: train/9_5220.jpg
#   inflating: train/9_9672.jpg
#   inflating: train/9_3680.jpg
#   inflating: train/9_7040.jpg
#   inflating: train/9_2808.jpg
#   inflating: train/9_7996.jpg
#   inflating: train/9_3305.jpg
#   inflating: train/9_2814.jpg
#   inflating: train/9_1494.jpg
#   inflating: train/9_2648.jpg
#   inflating: train/9_7330.jpg
#   inflating: train/9_9661.jpg
#   inflating: train/9_4056.jpg
#   inflating: train/9_414.jpg
#   inflating: train/9_1403.jpg
#   inflating: train/9_6239.jpg
#   inflating: train/9_6931.jpg
#   inflating: train/9_9216.jpg
#   inflating: train/9_6367.jpg
#   inflating: train/9_7771.jpg
#   inflating: train/9_5473.jpg
#   inflating: train/2_6632.jpg
#   inflating: train/2_1845.jpg
#   inflating: train/2_8227.jpg
#   inflating: train/2_3684.jpg
#   inflating: train/2_6616.jpg
#   inflating: train/2_3184.jpg
#   inflating: train/2_1251.jpg
#   inflating: train/2_345.jpg
#   inflating: train/2_6688.jpg
#   inflating: train/2_3484.jpg
#   inflating: train/2_6635.jpg
#   inflating: train/2_7308.jpg
#   inflating: train/2_7389.jpg
#   inflating: train/2_1956.jpg
#   inflating: train/2_1772.jpg
#   inflating: train/2_3944.jpg
#   inflating: train/2_1707.jpg
#   inflating: train/2_57.jpg
#   inflating: train/2_5625.jpg
#   inflating: train/2_1386.jpg
#   inflating: train/2_8256.jpg
#   inflating: train/7_5276.jpg
#   inflating: train/7_4777.jpg
#   inflating: train/7_3926.jpg
#   inflating: train/7_8204.jpg
#   inflating: train/7_4397.jpg
#   inflating: train/7_5039.jpg
#   inflating: train/7_9541.jpg
#   inflating: train/7_4253.jpg
#   inflating: train/7_5995.jpg
#   inflating: train/7_1415.jpg
#   inflating: train/7_6656.jpg
#   inflating: train/7_6312.jpg
#   inflating: train/7_7094.jpg
#   inflating: train/7_5269.jpg
#   inflating: train/7_5968.jpg
#   inflating: train/7_8734.jpg
#   inflating: train/7_1824.jpg
#   inflating: train/7_8619.jpg
#   inflating: train/7_1354.jpg
#   inflating: train/7_5293.jpg
#   inflating: train/7_7262.jpg
#   inflating: train/7_2661.jpg
#   inflating: train/7_3534.jpg
#   inflating: train/7_3878.jpg
#   inflating: train/7_1953.jpg
#   inflating: train/7_5436.jpg
#   inflating: train/7_9043.jpg
#   inflating: train/7_6708.jpg
#   inflating: train/7_1749.jpg
#   inflating: train/7_761.jpg
#   inflating: train/7_7501.jpg
#   inflating: train/7_1349.jpg
#   inflating: train/7_6253.jpg
#   inflating: train/7_5328.jpg
#   inflating: train/7_828.jpg
#   inflating: train/7_5933.jpg
#   inflating: train/7_7050.jpg
#   inflating: train/7_7508.jpg
#   inflating: train/7_2913.jpg
#   inflating: train/7_1380.jpg
#   inflating: train/7_5684.jpg
#   inflating: train/7_8988.jpg
#   inflating: train/7_9439.jpg
#   inflating: train/7_9508.jpg
#   inflating: train/7_8778.jpg
#   inflating: train/7_8676.jpg
#   inflating: train/7_9283.jpg
#   inflating: train/7_6289.jpg
#   inflating: train/7_9221.jpg
#   inflating: train/7_3542.jpg
#   inflating: train/7_9720.jpg
#   inflating: train/7_1008.jpg
#   inflating: train/7_2279.jpg
#   inflating: train/7_4877.jpg
#   inflating: train/7_4338.jpg
#   inflating: train/7_4683.jpg
#   inflating: train/7_9977.jpg
#   inflating: train/7_324.jpg
#   inflating: train/7_3613.jpg
#   inflating: train/7_4474.jpg
#   inflating: train/7_5264.jpg
#   inflating: train/7_1332.jpg
#   inflating: train/7_1673.jpg
#   inflating: train/7_5950.jpg
#   inflating: train/7_6747.jpg
#   inflating: train/7_8361.jpg
#   inflating: train/7_6026.jpg
#   inflating: train/7_8160.jpg
#   inflating: train/7_5824.jpg
#   inflating: train/7_5637.jpg
#   inflating: train/7_7430.jpg
#   inflating: train/7_8507.jpg
#   inflating: train/7_9281.jpg
#   inflating: train/7_1192.jpg
#   inflating: train/7_955.jpg
#   inflating: train/7_5879.jpg
#   inflating: train/7_148.jpg
#   inflating: train/7_6330.jpg
#   inflating: train/7_3411.jpg
#   inflating: train/7_1768.jpg
#   inflating: train/7_9504.jpg
#   inflating: train/7_1701.jpg
#   inflating: train/7_6531.jpg
#   inflating: train/7_3008.jpg
#   inflating: train/7_1219.jpg
#   inflating: train/7_4178.jpg
#   inflating: train/7_8071.jpg
#   inflating: train/7_8221.jpg
#   inflating: train/7_8272.jpg
#   inflating: train/7_8873.jpg
#   inflating: train/7_3905.jpg
#   inflating: train/7_2649.jpg
#   inflating: train/0_7039.jpg
#   inflating: train/0_7266.jpg
#   inflating: train/0_2461.jpg
#   inflating: train/0_8690.jpg
#   inflating: train/0_2107.jpg
#   inflating: train/0_585.jpg
#   inflating: train/0_6543.jpg
#   inflating: train/0_129.jpg
#   inflating: train/0_6851.jpg
#   inflating: train/0_8000.jpg
#   inflating: train/0_5117.jpg
#   inflating: train/0_7840.jpg
#   inflating: train/0_6892.jpg
#   inflating: train/0_8809.jpg
#   inflating: train/0_6953.jpg
#   inflating: train/0_1646.jpg
#   inflating: train/0_4663.jpg
#   inflating: train/0_1811.jpg
#   inflating: train/0_6327.jpg
#   inflating: train/0_9560.jpg
#   inflating: train/0_9148.jpg
#   inflating: train/0_3736.jpg
#   inflating: train/0_1240.jpg
#   inflating: train/0_3288.jpg
#   inflating: train/0_5497.jpg
#   inflating: train/0_4562.jpg
#   inflating: train/0_9707.jpg
#   inflating: train/0_6424.jpg
#   inflating: train/0_2806.jpg
#   inflating: train/0_378.jpg
#   inflating: train/0_1954.jpg
#   inflating: train/0_917.jpg
#   inflating: train/0_4247.jpg
#   inflating: train/0_7365.jpg
#   inflating: train/0_1381.jpg
#   inflating: train/0_5607.jpg
#   inflating: train/0_722.jpg
#   inflating: train/0_9641.jpg
#   inflating: train/0_7068.jpg
#   inflating: train/0_4935.jpg
#   inflating: train/0_8716.jpg
#   inflating: train/0_2876.jpg
#   inflating: train/0_8100.jpg
#   inflating: train/0_7971.jpg
#   inflating: train/0_8217.jpg
#   inflating: train/0_6840.jpg
#   inflating: train/0_6533.jpg
#   inflating: train/0_4589.jpg
#   inflating: train/0_7414.jpg
#   inflating: train/0_9305.jpg
#   inflating: train/0_8918.jpg
#   inflating: train/0_375.jpg
#   inflating: train/0_3741.jpg
#   inflating: train/0_2194.jpg
#   inflating: train/0_6095.jpg
#   inflating: train/0_3984.jpg
#   inflating: train/0_9949.jpg
#   inflating: train/0_2339.jpg
#   inflating: train/0_3929.jpg
#   inflating: train/0_7285.jpg
#   inflating: train/0_6053.jpg
#   inflating: train/0_3290.jpg
#   inflating: train/0_1606.jpg
#   inflating: train/6_4989.jpg
#   inflating: train/6_4288.jpg
#   inflating: train/6_2869.jpg
#   inflating: train/6_1087.jpg
#   inflating: train/6_1133.jpg
#   inflating: train/6_1190.jpg
#   inflating: train/6_7791.jpg
#   inflating: train/6_1958.jpg
#   inflating: train/6_160.jpg
#   inflating: train/6_3591.jpg
#   inflating: train/6_1891.jpg
#   inflating: train/6_170.jpg
#   inflating: train/6_3393.jpg
#   inflating: train/6_1852.jpg
#   inflating: train/6_3488.jpg
#   inflating: train/6_2516.jpg
#   inflating: train/6_9923.jpg
#   inflating: train/6_4616.jpg
#   inflating: train/6_7914.jpg
#   inflating: train/6_2690.jpg
#   inflating: train/6_7665.jpg
#   inflating: train/6_1513.jpg
#   inflating: train/6_6803.jpg
#   inflating: train/6_4416.jpg
#   inflating: train/6_6955.jpg
#   inflating: train/6_5106.jpg
#   inflating: train/6_1870.jpg
#   inflating: train/6_9053.jpg
#   inflating: train/6_9294.jpg
#   inflating: train/6_113.jpg
#   inflating: train/6_4315.jpg
#   inflating: train/6_3240.jpg
#   inflating: train/6_2632.jpg
#   inflating: train/6_8555.jpg
#   inflating: train/6_2003.jpg
#   inflating: train/6_5249.jpg
#   inflating: train/6_7142.jpg
#   inflating: train/6_5925.jpg
#   inflating: train/6_4163.jpg
#   inflating: train/6_94.jpg
#   inflating: train/6_7752.jpg
#   inflating: train/6_5077.jpg
#   inflating: train/6_3118.jpg
#   inflating: train/6_3451.jpg
#   inflating: train/6_4675.jpg
#   inflating: train/6_2195.jpg
#   inflating: train/6_731.jpg
#   inflating: train/6_1835.jpg
#   inflating: train/6_4036.jpg
#   inflating: train/6_8385.jpg
#   inflating: train/6_7466.jpg
#   inflating: train/6_6389.jpg
#   inflating: train/3_7442.jpg
#   inflating: train/3_4038.jpg
#   inflating: train/3_6489.jpg
#   inflating: train/3_4041.jpg
#   inflating: train/3_9038.jpg
#   inflating: train/3_6106.jpg
#   inflating: train/3_3576.jpg
#   inflating: train/3_5242.jpg
#   inflating: train/3_9025.jpg
#   inflating: train/3_8018.jpg
#   inflating: train/3_5202.jpg
#   inflating: train/3_6309.jpg
#   inflating: train/3_554.jpg
#   inflating: train/3_3150.jpg
#   inflating: train/3_3840.jpg
#   inflating: train/3_8152.jpg
#   inflating: train/3_831.jpg
#   inflating: train/3_4287.jpg
#   inflating: train/3_7119.jpg
#   inflating: train/3_9070.jpg
#   inflating: train/3_8949.jpg
#   inflating: train/3_9635.jpg
#   inflating: train/3_6530.jpg
#   inflating: train/3_935.jpg
#   inflating: train/3_2394.jpg
#   inflating: train/3_4171.jpg
#   inflating: train/3_9479.jpg
#   inflating: train/3_3176.jpg
#   inflating: train/3_1232.jpg
#   inflating: train/3_3075.jpg
#   inflating: train/3_7473.jpg
#   inflating: train/3_8515.jpg
#   inflating: train/3_1202.jpg
#   inflating: train/3_4266.jpg
#   inflating: train/3_9998.jpg
#   inflating: train/3_6938.jpg
#   inflating: train/3_91.jpg
#   inflating: train/3_8093.jpg
#   inflating: train/3_3158.jpg
#   inflating: train/3_5766.jpg
#   inflating: train/3_7343.jpg
#   inflating: train/3_463.jpg
#   inflating: train/3_1315.jpg
#   inflating: train/3_7418.jpg
#   inflating: train/3_9390.jpg
#   inflating: train/3_9972.jpg
#   inflating: train/3_7636.jpg
#   inflating: train/3_5777.jpg
#   inflating: train/3_2769.jpg
#   inflating: train/3_7695.jpg
#   inflating: train/3_5987.jpg
#   inflating: train/3_4108.jpg
#   inflating: train/3_7298.jpg
#   inflating: train/3_8019.jpg
#   inflating: train/3_9555.jpg
#   inflating: train/3_847.jpg
#   inflating: train/3_7807.jpg
#   inflating: train/3_9817.jpg
#   inflating: train/3_3711.jpg
#   inflating: train/3_1034.jpg
#   inflating: train/3_4726.jpg
#   inflating: train/3_5778.jpg
#   inflating: train/3_4699.jpg
#   inflating: train/3_4544.jpg
#   inflating: train/3_4812.jpg
#   inflating: train/3_9266.jpg
#   inflating: train/3_7852.jpg
#   inflating: train/3_3065.jpg
#   inflating: train/3_8914.jpg
#   inflating: train/5_590.jpg
#   inflating: train/5_7845.jpg
#   inflating: train/5_9234.jpg
#   inflating: train/5_5069.jpg
#   inflating: train/5_3643.jpg
#   inflating: train/5_2560.jpg
#   inflating: train/5_4017.jpg
#   inflating: train/5_2984.jpg
#   inflating: train/5_4413.jpg
#   inflating: train/5_3779.jpg
#   inflating: train/5_2447.jpg
#   inflating: train/5_5573.jpg
#   inflating: train/5_1241.jpg
#   inflating: train/5_2628.jpg
#   inflating: train/5_9223.jpg
#   inflating: train/5_279.jpg
#   inflating: train/5_5068.jpg
#   inflating: train/5_7854.jpg
#   inflating: train/5_7805.jpg
#   inflating: train/5_4605.jpg
#   inflating: train/5_2914.jpg
#   inflating: train/5_5635.jpg
#   inflating: train/5_5452.jpg
#   inflating: train/5_4330.jpg
#   inflating: train/4_5487.jpg
#   inflating: train/4_3766.jpg
#   inflating: train/4_1326.jpg
#   inflating: train/4_5155.jpg
#   inflating: train/4_4035.jpg
#   inflating: train/4_2084.jpg
#   inflating: train/4_7703.jpg
#   inflating: train/4_6933.jpg
#   inflating: train/4_4512.jpg
#   inflating: train/4_3599.jpg
#   inflating: train/4_1651.jpg
#   inflating: train/10_6932.jpg
#   inflating: train/10_4173.jpg
#   inflating: train/10_1426.jpg
#   inflating: train/10_2169.jpg
#   inflating: train/10_337.jpg
#   inflating: train/10_3685.jpg
#   inflating: train/10_3497.jpg
#   inflating: train/10_767.jpg
#   inflating: train/10_6028.jpg
#   inflating: train/10_1246.jpg
#   inflating: train/10_6074.jpg
#   inflating: train/10_3188.jpg
#   inflating: train/10_2222.jpg
#   inflating: train/10_1766.jpg
#   inflating: train/10_7720.jpg
#   inflating: train/10_3463.jpg
#   inflating: train/10_3170.jpg
#   inflating: train/10_5349.jpg
#   inflating: train/10_4834.jpg
#   inflating: train/10_5189.jpg
#   inflating: train/10_8837.jpg
#   inflating: train/10_6650.jpg
#   inflating: train/10_2652.jpg
#   inflating: train/10_1723.jpg
#   inflating: train/10_8847.jpg
#   inflating: train/10_5237.jpg
#   inflating: train/10_7816.jpg
#   inflating: train/10_9123.jpg
#   inflating: train/10_8357.jpg
#   inflating: train/10_7626.jpg
#   inflating: train/10_1670.jpg
#   inflating: train/10_8698.jpg
#   inflating: train/10_8475.jpg
#   inflating: train/10_4599.jpg
#   inflating: train/10_7574.jpg
#   inflating: train/10_3196.jpg
#   inflating: train/10_1213.jpg
#   inflating: train/10_3077.jpg
#   inflating: train/10_5730.jpg
#   inflating: train/10_6665.jpg
#   inflating: train/10_801.jpg
#   inflating: train/10_1779.jpg
#   inflating: train/10_7993.jpg
#   inflating: train/10_8495.jpg
#   inflating: train/10_5504.jpg
#   inflating: train/10_7558.jpg
#   inflating: train/10_1795.jpg
#   inflating: train/10_7643.jpg
#   inflating: train/10_6421.jpg
#   inflating: train/10_596.jpg
#   inflating: train/1_314.jpg
#   inflating: train/1_7063.jpg
#   inflating: train/1_591.jpg
#   inflating: train/1_6264.jpg
#   inflating: train/1_2631.jpg
#   inflating: train/1_8170.jpg
#   inflating: train/1_6912.jpg
#   inflating: train/1_6842.jpg
#   inflating: train/1_1166.jpg
#   inflating: train/1_6096.jpg
#   inflating: train/1_9309.jpg
#   inflating: train/1_122.jpg
#   inflating: train/1_8105.jpg
#   inflating: train/1_6449.jpg
#   inflating: train/1_9597.jpg
#   inflating: train/1_7156.jpg
#   inflating: train/1_3475.jpg
#   inflating: train/1_2838.jpg
#   inflating: train/1_2120.jpg
#   inflating: train/1_3189.jpg
#   inflating: train/1_7930.jpg
#   inflating: train/1_8575.jpg
#   inflating: train/1_3702.jpg
#   inflating: train/1_507.jpg
#   inflating: train/1_3881.jpg
#   inflating: train/1_4151.jpg
#   inflating: train/1_136.jpg
#   inflating: train/1_5268.jpg
#   inflating: train/1_9178.jpg
#   inflating: train/1_9685.jpg
#   inflating: train/1_3361.jpg
#   inflating: train/1_4457.jpg
#   inflating: train/1_7576.jpg
#   inflating: train/1_6774.jpg
#   inflating: train/1_1009.jpg
#   inflating: train/1_9836.jpg
#   inflating: train/1_9574.jpg
#   inflating: train/1_4555.jpg
#   inflating: train/1_495.jpg
#   inflating: train/1_5343.jpg
#   inflating: train/1_8979.jpg
#   inflating: train/1_3664.jpg
#   inflating: train/1_3608.jpg
#   inflating: train/1_9278.jpg
#   inflating: train/1_4625.jpg
#   inflating: train/1_5207.jpg
#   inflating: train/1_3886.jpg
#   inflating: train/1_5781.jpg
#   inflating: train/1_9035.jpg
#   inflating: train/1_6072.jpg
#   inflating: train/1_4515.jpg
#   inflating: train/1_2432.jpg
#   inflating: train/1_9119.jpg
#   inflating: train/1_1694.jpg
#   inflating: train/1_8442.jpg
#   inflating: train/1_9071.jpg
#   inflating: train/1_8186.jpg
#   inflating: train/1_6619.jpg
#   inflating: train/1_4188.jpg
#   inflating: train/1_1338.jpg
#   inflating: train/1_6737.jpg
#   inflating: train/1_8420.jpg
#   inflating: train/1_7235.jpg
#   inflating: train/1_8169.jpg
#   inflating: train/1_9826.jpg
#   inflating: train/1_803.jpg
#   inflating: train/1_5427.jpg
#   inflating: train/1_4731.jpg
#   inflating: train/1_6419.jpg
#   inflating: train/1_6507.jpg
#   inflating: train/1_5481.jpg
#   inflating: train/1_8870.jpg
#   inflating: train/1_3341.jpg
#   inflating: train/1_7347.jpg
#   inflating: train/1_3046.jpg
#   inflating: train/1_1744.jpg
#   inflating: train/1_9611.jpg
#   inflating: train/1_1889.jpg
#   inflating: train/1_8618.jpg
#   inflating: train/1_862.jpg
#   inflating: train/1_3939.jpg
#   inflating: train/1_5587.jpg
#   inflating: train/1_4099.jpg
#   inflating: train/1_9908.jpg
#   inflating: train/1_2983.jpg
#   inflating: train/1_5796.jpg
#   inflating: train/1_9248.jpg
#   inflating: train/1_2051.jpg
#   inflating: train/1_4521.jpg
#   inflating: train/1_1228.jpg
#   inflating: train/1_1131.jpg
#   inflating: train/1_159.jpg
#   inflating: train/1_3566.jpg
#   inflating: train/1_32.jpg
#   inflating: train/1_5191.jpg
#   inflating: train/1_3354.jpg
#   inflating: train/1_2564.jpg
#   inflating: train/1_560.jpg
#   inflating: train/1_5401.jpg
#   inflating: train/1_8508.jpg
#   inflating: train/1_2325.jpg
#   inflating: train/1_8866.jpg
#   inflating: train/1_5871.jpg
#   inflating: train/1_3820.jpg
#   inflating: train/1_9631.jpg
#   inflating: train/1_1496.jpg
#   inflating: train/1_5749.jpg
#   inflating: train/1_6136.jpg
#   inflating: train/1_3333.jpg
#   inflating: train/1_4601.jpg
#   inflating: train/1_1564.jpg
#   inflating: train/8_1181.jpg
#   inflating: train/8_5535.jpg
#   inflating: train/8_8661.jpg
#   inflating: train/8_2266.jpg
#   inflating: train/8_6689.jpg
#   inflating: train/8_9154.jpg
#   inflating: train/8_953.jpg
#   inflating: train/8_9133.jpg
#   inflating: train/8_4382.jpg
#   inflating: train/8_1647.jpg
#   inflating: train/8_8468.jpg
#   inflating: train/8_3649.jpg
#   inflating: train/8_8315.jpg
#   inflating: train/8_2059.jpg
#   inflating: train/8_7352.jpg
#   inflating: train/8_7555.jpg
#   inflating: train/8_5057.jpg
#   inflating: train/8_9243.jpg
#   inflating: train/8_8595.jpg
#   inflating: train/8_2147.jpg
#   inflating: train/8_693.jpg
#   inflating: train/8_6684.jpg
#   inflating: train/8_2008.jpg
#   inflating: train/8_2043.jpg
#   inflating: train/8_9547.jpg
#   inflating: train/8_1698.jpg
#   inflating: train/8_2722.jpg
#   inflating: train/8_5857.jpg
#   inflating: train/8_5075.jpg
#   inflating: train/9_5122.jpg
#   inflating: train/9_9376.jpg
#   inflating: train/9_7034.jpg
#   inflating: train/9_8920.jpg
#   inflating: train/9_7392.jpg
#   inflating: train/9_7787.jpg
#   inflating: train/9_8712.jpg
#   inflating: train/9_3603.jpg
#   inflating: train/9_6858.jpg
#   inflating: train/9_7445.jpg
#   inflating: train/9_9851.jpg
#   inflating: train/9_9001.jpg
#   inflating: train/9_6948.jpg
#   inflating: train/9_4638.jpg
#   inflating: train/9_3114.jpg
#   inflating: train/9_5812.jpg
#   inflating: train/9_6542.jpg
#   inflating: train/2_9528.jpg
#   inflating: train/2_7211.jpg
#   inflating: train/2_792.jpg
#   inflating: train/2_418.jpg
#   inflating: train/2_5681.jpg
#   inflating: train/2_8113.jpg
#   inflating: train/2_2062.jpg
#   inflating: train/2_320.jpg
#   inflating: train/7_4290.jpg
#   inflating: train/7_265.jpg
#   inflating: train/7_2795.jpg
#   inflating: train/7_6631.jpg
#   inflating: train/7_6115.jpg
#   inflating: train/7_8625.jpg
#   inflating: train/7_7052.jpg
#   inflating: train/7_7209.jpg
#   inflating: train/7_2772.jpg
#   inflating: train/7_8036.jpg
#   inflating: train/7_968.jpg
#   inflating: train/7_8220.jpg
#   inflating: train/7_647.jpg
#   inflating: train/7_5092.jpg
#   inflating: train/7_6717.jpg
#   inflating: train/7_741.jpg
#   inflating: train/7_7139.jpg
#   inflating: train/7_6682.jpg
#   inflating: train/7_7937.jpg
#   inflating: train/7_2774.jpg
#   inflating: train/7_107.jpg
#   inflating: train/7_5458.jpg
#   inflating: train/7_141.jpg
#   inflating: train/7_2015.jpg
#   inflating: train/7_2603.jpg
#   inflating: train/7_841.jpg
#   inflating: train/7_592.jpg
#   inflating: train/7_2930.jpg
#   inflating: train/7_7859.jpg
#   inflating: train/0_1374.jpg
#   inflating: train/0_8012.jpg
#   inflating: train/0_8780.jpg
#   inflating: train/0_3838.jpg
#   inflating: train/0_9997.jpg
#   inflating: train/0_384.jpg
#   inflating: train/0_4773.jpg
#   inflating: train/0_7492.jpg
#   inflating: train/0_8802.jpg
#   inflating: train/0_2846.jpg
#   inflating: train/0_4747.jpg
#   inflating: train/0_6471.jpg
#   inflating: train/0_6502.jpg
#   inflating: train/0_3857.jpg
#   inflating: train/0_4721.jpg
#   inflating: train/0_8278.jpg
#   inflating: train/0_5256.jpg
#   inflating: train/0_4295.jpg
#   inflating: train/0_1655.jpg
#   inflating: train/6_1887.jpg
#   inflating: train/6_5993.jpg
#   inflating: train/6_1625.jpg
#   inflating: train/6_1253.jpg
#   inflating: train/6_690.jpg
#   inflating: train/6_3913.jpg
#   inflating: train/6_7750.jpg
#   inflating: train/6_7358.jpg
#   inflating: train/6_4528.jpg
#   inflating: train/6_1450.jpg
#   inflating: train/6_3016.jpg
#   inflating: train/6_3417.jpg
#   inflating: train/6_3750.jpg
#   inflating: train/3_4133.jpg
#   inflating: train/3_4073.jpg
#   inflating: train/3_1492.jpg
#   inflating: train/3_2066.jpg
#   inflating: train/3_1252.jpg
#   inflating: train/3_4228.jpg
#   inflating: train/3_7882.jpg
#   inflating: train/3_1102.jpg
#   inflating: train/3_9867.jpg
#   inflating: train/3_7561.jpg
#   inflating: train/3_3423.jpg
#   inflating: train/3_1070.jpg
#   inflating: train/3_918.jpg
#   inflating: train/3_8373.jpg
#   inflating: train/3_2167.jpg
#   inflating: train/3_5845.jpg
#   inflating: train/3_1728.jpg
#   inflating: train/3_1029.jpg
#   inflating: train/3_3618.jpg
#   inflating: train/3_7893.jpg
#   inflating: train/3_7810.jpg
#   inflating: train/3_5664.jpg
#   inflating: train/3_3721.jpg
#   inflating: train/3_2667.jpg
#   inflating: train/5_8819.jpg
#   inflating: train/5_1080.jpg
#   inflating: train/5_9950.jpg
#   inflating: train/5_5030.jpg
#   inflating: train/5_9779.jpg
#   inflating: train/5_1752.jpg
#   inflating: train/5_357.jpg
#   inflating: train/5_3482.jpg
#   inflating: train/5_7520.jpg
#   inflating: train/5_6099.jpg
#   inflating: train/5_4536.jpg
#   inflating: train/4_7837.jpg
#   inflating: train/4_5302.jpg
#   inflating: train/4_3390.jpg
#   inflating: train/4_3323.jpg
#   inflating: train/4_5621.jpg
#   inflating: train/4_9346.jpg
#   inflating: train/4_1138.jpg
#   inflating: train/4_9081.jpg
#   inflating: train/10_9466.jpg
#   inflating: train/10_9052.jpg
#   inflating: train/10_1679.jpg
#   inflating: train/10_1101.jpg
#   inflating: train/10_8538.jpg
#   inflating: train/10_4884.jpg
#   inflating: train/10_4177.jpg
#   inflating: train/10_9273.jpg
#   inflating: train/10_9824.jpg
#   inflating: train/10_8165.jpg
#   inflating: train/10_8814.jpg
#   inflating: train/10_3056.jpg
#   inflating: train/10_3257.jpg
#   inflating: train/10_888.jpg
#   inflating: train/10_2647.jpg
#   inflating: train/10_349.jpg
#   inflating: train/10_370.jpg
#   inflating: train/10_8928.jpg
#   inflating: train/10_6841.jpg
#   inflating: train/10_3194.jpg
#   inflating: train/1_1926.jpg
#   inflating: train/1_3821.jpg
#   inflating: train/1_4254.jpg
#   inflating: train/1_6852.jpg
#   inflating: train/1_3774.jpg
#   inflating: train/1_9533.jpg
#   inflating: train/1_1600.jpg
#   inflating: train/1_4051.jpg
#   inflating: train/1_3577.jpg
#   inflating: train/1_867.jpg
#   inflating: train/1_1969.jpg
#   inflating: train/1_3720.jpg
#   inflating: train/1_6637.jpg
#   inflating: train/1_7598.jpg
#   inflating: train/1_4972.jpg
#   inflating: train/1_8216.jpg
#   inflating: train/1_2436.jpg
#   inflating: train/1_137.jpg
#   inflating: train/1_9249.jpg
#   inflating: train/1_7603.jpg
#   inflating: train/1_7659.jpg
#   inflating: train/1_2261.jpg
#   inflating: train/1_9191.jpg
#   inflating: train/1_2087.jpg
#   inflating: train/1_6598.jpg
#   inflating: train/1_2855.jpg
#   inflating: train/1_1506.jpg
#   inflating: train/1_3570.jpg
#   inflating: train/1_9512.jpg
#   inflating: train/8_6909.jpg
#   inflating: train/8_4232.jpg
#   inflating: train/8_6861.jpg
#   inflating: train/8_9181.jpg
#   inflating: train/8_1296.jpg
#   inflating: train/8_8463.jpg
#   inflating: train/8_443.jpg
#   inflating: train/8_9230.jpg
#   inflating: train/8_9451.jpg
#   inflating: train/8_8350.jpg
#   inflating: train/8_1433.jpg
#   inflating: train/8_7596.jpg
#   inflating: train/8_7648.jpg
#   inflating: train/8_7870.jpg
#   inflating: train/8_4463.jpg
#   inflating: train/8_2244.jpg
#   inflating: train/9_7363.jpg
#   inflating: train/9_6336.jpg
#   inflating: train/9_4736.jpg
#   inflating: train/9_3538.jpg
#   inflating: train/9_1206.jpg
#   inflating: train/9_9311.jpg
#   inflating: train/9_7340.jpg
#   inflating: train/9_9161.jpg
#   inflating: train/9_3018.jpg
#   inflating: train/9_3026.jpg
#   inflating: train/9_8195.jpg
#   inflating: train/9_8673.jpg
#   inflating: train/9_9926.jpg
#   inflating: train/9_9317.jpg
#   inflating: train/9_7639.jpg
#   inflating: train/9_4895.jpg
#   inflating: train/9_3041.jpg
#   inflating: train/9_5665.jpg
#   inflating: train/9_5945.jpg
#   inflating: train/9_8880.jpg
#   inflating: train/9_5236.jpg
#   inflating: train/9_8945.jpg
#   inflating: train/9_9629.jpg
#   inflating: train/9_9160.jpg
#   inflating: train/9_6198.jpg
#   inflating: train/2_4786.jpg
#   inflating: train/2_5380.jpg
#   inflating: train/2_8843.jpg
#   inflating: train/2_9749.jpg
#   inflating: train/2_2780.jpg
#   inflating: train/2_5899.jpg
#   inflating: train/7_1898.jpg
#   inflating: train/7_7160.jpg
#   inflating: train/7_1327.jpg
#   inflating: train/7_6201.jpg
#   inflating: train/7_4890.jpg
#   inflating: train/7_7386.jpg
#   inflating: train/7_1180.jpg
#   inflating: train/7_4696.jpg
#   inflating: train/7_4871.jpg
#   inflating: train/7_3385.jpg
#   inflating: train/7_7104.jpg
#   inflating: train/7_7335.jpg
#   inflating: train/7_821.jpg
#   inflating: train/7_6837.jpg
#   inflating: train/7_5609.jpg
#   inflating: train/7_5794.jpg
#   inflating: train/7_7121.jpg
#   inflating: train/7_8504.jpg
#   inflating: train/7_7012.jpg
#   inflating: train/7_5035.jpg
#   inflating: train/7_5044.jpg
#   inflating: train/7_3381.jpg
#   inflating: train/7_3530.jpg
#   inflating: train/0_3198.jpg
#   inflating: train/0_1715.jpg
#   inflating: train/0_1126.jpg
#   inflating: train/0_3985.jpg
#   inflating: train/0_4396.jpg
#   inflating: train/0_8641.jpg
#   inflating: train/0_3669.jpg
#   inflating: train/0_6376.jpg
#   inflating: train/0_8476.jpg
#   inflating: train/0_7272.jpg
#   inflating: train/0_9695.jpg
#   inflating: train/0_3638.jpg
#   inflating: train/0_848.jpg
#   inflating: train/0_8355.jpg
#   inflating: train/0_6442.jpg
#   inflating: train/0_3654.jpg
#   inflating: train/0_1590.jpg
#   inflating: train/0_2165.jpg
#   inflating: train/0_1276.jpg
#   inflating: train/0_9091.jpg
#   inflating: train/0_6693.jpg
#   inflating: train/0_5746.jpg
#   inflating: train/6_5211.jpg
#   inflating: train/6_1649.jpg
#   inflating: train/6_6602.jpg
#   inflating: train/6_8423.jpg
#   inflating: train/6_2101.jpg
#   inflating: train/6_9791.jpg
#   inflating: train/6_385.jpg
#   inflating: train/6_2964.jpg
#   inflating: train/6_6043.jpg
#   inflating: train/6_1104.jpg
#   inflating: train/6_6781.jpg
#   inflating: train/6_3119.jpg
#   inflating: train/6_3875.jpg
#   inflating: train/6_6967.jpg
#   inflating: train/6_7008.jpg
#   inflating: train/3_9381.jpg
#   inflating: train/3_7002.jpg
#   inflating: train/3_4321.jpg
#   inflating: train/3_2402.jpg
#   inflating: train/3_7254.jpg
#   inflating: train/3_1597.jpg
#   inflating: train/3_2346.jpg
#   inflating: train/3_7848.jpg
#   inflating: train/3_8021.jpg
#   inflating: train/3_4629.jpg
#   inflating: train/3_1208.jpg
#   inflating: train/3_248.jpg
#   inflating: train/3_4195.jpg
#   inflating: train/3_9845.jpg
#   inflating: train/3_1992.jpg
#   inflating: train/3_220.jpg
#   inflating: train/3_6991.jpg
#   inflating: train/3_9192.jpg
#   inflating: train/3_2728.jpg
#   inflating: train/5_3536.jpg
#   inflating: train/5_660.jpg
#   inflating: train/5_8151.jpg
#   inflating: train/5_6514.jpg
#   inflating: train/5_3282.jpg
#   inflating: train/5_5652.jpg
#   inflating: train/5_7165.jpg
#   inflating: train/5_9128.jpg
#   inflating: train/5_7009.jpg
#   inflating: train/4_5032.jpg
#   inflating: train/4_5255.jpg
#   inflating: train/4_6672.jpg
#   inflating: train/4_3122.jpg
#   inflating: train/10_6094.jpg
#   inflating: train/10_2856.jpg
#   inflating: train/10_4926.jpg
#   inflating: train/10_3156.jpg
#   inflating: train/10_3342.jpg
#   inflating: train/10_2924.jpg
#   inflating: train/10_9810.jpg
#   inflating: train/10_6062.jpg
#   inflating: train/10_7846.jpg
#   inflating: train/10_6495.jpg
#   inflating: train/10_8933.jpg
#   inflating: train/10_4597.jpg
#   inflating: train/10_6100.jpg
#   inflating: train/10_4667.jpg
#   inflating: train/10_2228.jpg
#   inflating: train/1_1931.jpg
#   inflating: train/1_7841.jpg
#   inflating: train/1_1223.jpg
#   inflating: train/1_2675.jpg
#   inflating: train/1_9789.jpg
#   inflating: train/1_7138.jpg
#   inflating: train/1_6794.jpg
#   inflating: train/1_6818.jpg
#   inflating: train/1_3149.jpg
#   inflating: train/1_5148.jpg
#   inflating: train/1_8252.jpg
#   inflating: train/1_5967.jpg
#   inflating: train/1_1610.jpg
#   inflating: train/1_2663.jpg
#   inflating: train/1_5467.jpg
#   inflating: train/1_4339.jpg
#   inflating: train/1_3825.jpg
#   inflating: train/1_4375.jpg
#   inflating: train/1_6528.jpg
#   inflating: train/1_8063.jpg
#   inflating: train/1_991.jpg
#   inflating: train/1_8813.jpg
#   inflating: train/1_9681.jpg
#   inflating: train/1_4324.jpg
#   inflating: train/1_1531.jpg
#   inflating: train/1_8013.jpg
#   inflating: train/1_3847.jpg
#   inflating: train/8_656.jpg
#   inflating: train/8_5678.jpg
#   inflating: train/8_1668.jpg
#   inflating: train/8_4998.jpg
#   inflating: train/8_613.jpg
#   inflating: train/8_7478.jpg
#   inflating: train/8_7046.jpg
#   inflating: train/8_4241.jpg
#   inflating: train/8_7905.jpg
#   inflating: train/8_5793.jpg
#   inflating: train/8_7902.jpg
#   inflating: train/8_302.jpg
#   inflating: train/8_6401.jpg
#   inflating: train/8_715.jpg
#   inflating: train/8_3951.jpg
#   inflating: train/8_7715.jpg
#   inflating: train/8_7517.jpg
#   inflating: train/8_4836.jpg
#   inflating: train/8_8171.jpg
#   inflating: train/8_6562.jpg
#   inflating: train/8_5384.jpg
#   inflating: train/8_5645.jpg
#   inflating: train/8_5611.jpg
#   inflating: train/8_2662.jpg
#   inflating: train/9_7016.jpg
#   inflating: train/9_1059.jpg
#   inflating: train/9_5406.jpg
#   inflating: train/9_8598.jpg
#   inflating: train/9_2908.jpg
#   inflating: train/9_1136.jpg
#   inflating: train/9_4201.jpg
#   inflating: train/9_3127.jpg
#   inflating: train/9_2025.jpg
#   inflating: train/9_2574.jpg
#   inflating: train/9_5004.jpg
#   inflating: train/9_1200.jpg
#   inflating: train/9_7727.jpg
#   inflating: train/9_9095.jpg
#   inflating: train/9_3289.jpg
#   inflating: train/9_1113.jpg
#   inflating: train/9_5884.jpg
#   inflating: train/9_7935.jpg
#   inflating: train/9_5859.jpg
#   inflating: train/9_9747.jpg
#   inflating: train/9_3155.jpg
#   inflating: train/9_6208.jpg
#   inflating: train/9_819.jpg
#   inflating: train/9_7438.jpg
#   inflating: train/9_7769.jpg
#   inflating: train/9_5491.jpg
#   inflating: train/9_6741.jpg
#   inflating: train/9_3276.jpg
#   inflating: train/9_3610.jpg
#   inflating: train/9_1750.jpg
#   inflating: train/9_530.jpg
#   inflating: train/9_7368.jpg
#   inflating: train/9_2994.jpg
#   inflating: train/9_701.jpg
#   inflating: train/9_1329.jpg
#   inflating: train/9_4881.jpg
#   inflating: train/9_7992.jpg
#   inflating: train/9_4386.jpg
#   inflating: train/9_6617.jpg
#   inflating: train/9_3712.jpg
#   inflating: train/9_2923.jpg
#   inflating: train/9_2201.jpg
#   inflating: train/9_9995.jpg
#   inflating: train/9_883.jpg
#   inflating: train/9_3837.jpg
#   inflating: train/9_7056.jpg
#   inflating: train/9_9561.jpg
#   inflating: train/9_7868.jpg
#   inflating: train/9_542.jpg
#   inflating: train/9_4372.jpg
#   inflating: train/9_5586.jpg
#   inflating: train/9_826.jpg
#   inflating: train/9_7005.jpg
#   inflating: train/9_2422.jpg
#   inflating: train/9_7255.jpg
#   inflating: train/9_5619.jpg
#   inflating: train/9_2708.jpg
#   inflating: train/9_9589.jpg
#   inflating: train/9_2395.jpg
#   inflating: train/9_5443.jpg
#   inflating: train/9_4476.jpg
#   inflating: train/2_4967.jpg
#   inflating: train/2_7532.jpg
#   inflating: train/2_5431.jpg
#   inflating: train/2_1309.jpg
#   inflating: train/2_7784.jpg
#   inflating: train/2_6981.jpg
#   inflating: train/2_3249.jpg
#   inflating: train/2_8878.jpg
#   inflating: train/2_4014.jpg
#   inflating: train/2_6669.jpg
#   inflating: train/2_2726.jpg
#   inflating: train/2_3359.jpg
#   inflating: train/2_7215.jpg
# ...
#   inflating: test/2688.jpg
#   inflating: test/0317.jpg
#   inflating: test/0850.jpg
#   inflating: test/2260.jpg
#   inflating: test/2187.jpg
#   inflating: test/0100.jpg
#   inflating: test/0958.jpg
#   inflating: test/0272.jpg
#   inflating: test/1335.jpg
#   inflating: test/1950.jpg
#   inflating: test/2830.jpg
#   inflating: test/2221.jpg
#   inflating: test/1783.jpg
#   inflating: test/2053.jpg
#   inflating: test/1839.jpg
#   inflating: test/1088.jpg
#   inflating: test/0486.jpg
#   inflating: test/2764.jpg
#   inflating: test/1946.jpg
#   inflating: test/2355.jpg
#   inflating: test/2778.jpg
#   inflating: test/2125.jpg
#   inflating: test/1027.jpg
#   inflating: test/1871.jpg
#   inflating: test/1624.jpg
#   inflating: test/0161.jpg
#   inflating: test/2059.jpg
#   inflating: test/2827.jpg
#   inflating: test/0921.jpg
#   inflating: test/1489.jpg
#   inflating: test/1940.jpg
#   inflating: test/1834.jpg
#   inflating: test/1214.jpg
#   inflating: test/2414.jpg
#   inflating: test/1640.jpg
#   inflating: test/2254.jpg
#   inflating: test/2873.jpg
#   inflating: test/1252.jpg
#   inflating: test/0169.jpg
#   inflating: test/0766.jpg
#   inflating: test/0403.jpg
#   inflating: test/2887.jpg
#   inflating: test/2936.jpg
#   inflating: test/1910.jpg
#   inflating: test/0975.jpg
#   inflating: test/0259.jpg
#   inflating: test/0051.jpg
#   inflating: test/0800.jpg
#   inflating: test/1164.jpg
#   inflating: test/0209.jpg
#   inflating: test/0924.jpg
#   inflating: test/1767.jpg
#   inflating: test/1457.jpg
#   inflating: test/0600.jpg
#   inflating: test/1403.jpg
#   inflating: test/1822.jpg
#   inflating: test/1982.jpg
#   inflating: test/0529.jpg
#   inflating: test/1105.jpg
#   inflating: test/2651.jpg
#   inflating: test/1770.jpg
#   inflating: test/2272.jpg
#   inflating: test/0518.jpg
#   inflating: test/2018.jpg
#   inflating: test/2312.jpg
#   inflating: test/1697.jpg
#   inflating: test/0572.jpg
#   inflating: test/2243.jpg
#   inflating: test/1748.jpg
#   inflating: test/2092.jpg
#   inflating: test/2487.jpg
#   inflating: test/1353.jpg
#   inflating: test/2645.jpg
#   inflating: test/1635.jpg
#   inflating: test/1240.jpg
#   inflating: test/1421.jpg
#   inflating: test/1524.jpg
#   inflating: test/0889.jpg
#   inflating: test/0715.jpg
#   inflating: test/1887.jpg
#   inflating: test/2654.jpg
#   inflating: test/2998.jpg
#   inflating: test/1254.jpg
#   inflating: test/1838.jpg
#   inflating: test/1142.jpg
#   inflating: test/1691.jpg
#   inflating: test/2439.jpg
#   inflating: test/0361.jpg
#   inflating: test/0516.jpg
#   inflating: test/2445.jpg
#   inflating: test/0013.jpg
#   inflating: test/2719.jpg
#   inflating: test/0615.jpg
#   inflating: test/2494.jpg
#   inflating: test/0989.jpg
#   inflating: test/1803.jpg
#   inflating: test/2828.jpg
#   inflating: test/0774.jpg
#   inflating: test/0408.jpg
#   inflating: test/0998.jpg
#   inflating: test/2176.jpg
#   inflating: test/2302.jpg
#   inflating: test/2271.jpg
#   inflating: test/2142.jpg
#   inflating: test/0829.jpg
#   inflating: test/0436.jpg
#   inflating: test/1436.jpg
#   inflating: test/2298.jpg
#   inflating: test/2282.jpg
#   inflating: test/2227.jpg
#   inflating: test/2366.jpg
#   inflating: test/0125.jpg
#   inflating: test/1742.jpg
#   inflating: test/1857.jpg
#   inflating: test/1617.jpg
#   inflating: test/2920.jpg
#   inflating: test/2536.jpg
#   inflating: test/0105.jpg
#   inflating: test/1475.jpg
#   inflating: test/1039.jpg
#   inflating: test/1999.jpg
#   inflating: test/0748.jpg
#   inflating: test/0752.jpg
#   inflating: test/1545.jpg
#   inflating: test/2144.jpg
#   inflating: test/2630.jpg
#   inflating: test/1314.jpg
#   inflating: test/2432.jpg
#   inflating: test/0039.jpg
#   inflating: test/1083.jpg
#   inflating: test/2069.jpg
#   inflating: test/1939.jpg
#   inflating: test/0370.jpg
#   inflating: test/0948.jpg
#   inflating: test/2608.jpg
#   inflating: test/2014.jpg
#   inflating: test/1349.jpg
#   inflating: test/2434.jpg
#   inflating: test/2616.jpg
#   inflating: test/0095.jpg
#   inflating: test/2739.jpg
#   inflating: test/0538.jpg
#   inflating: test/1198.jpg
#   inflating: test/1569.jpg
#   inflating: test/0493.jpg
#   inflating: test/2518.jpg
#   inflating: test/0605.jpg
#   inflating: test/2503.jpg
#   inflating: test/0934.jpg
#   inflating: test/2728.jpg
#   inflating: test/2043.jpg
#   inflating: test/0119.jpg
#   inflating: test/0410.jpg
#   inflating: test/1437.jpg
#   inflating: test/2270.jpg
#   inflating: test/0094.jpg
#   inflating: test/0738.jpg
#   inflating: test/2177.jpg
#   inflating: test/2288.jpg
#   inflating: test/1429.jpg
#   inflating: test/0207.jpg
#   inflating: test/1065.jpg
#   inflating: test/2963.jpg
#   inflating: test/2181.jpg
#   inflating: test/2240.jpg
#   inflating: test/1644.jpg
#   inflating: test/1392.jpg
#   inflating: test/2384.jpg
#   inflating: test/0854.jpg
#   inflating: test/2684.jpg
#   inflating: test/2339.jpg
#   inflating: test/2802.jpg
#   inflating: test/0172.jpg
#   inflating: test/0120.jpg
#   inflating: test/1908.jpg
#   inflating: test/1377.jpg
#   inflating: test/2497.jpg
#   inflating: test/2124.jpg
#   inflating: test/2711.jpg
#   inflating: test/2986.jpg
#   inflating: test/1447.jpg
#   inflating: test/2324.jpg
#   inflating: test/1653.jpg
#   inflating: test/1527.jpg
#   inflating: test/2940.jpg
#   inflating: test/1159.jpg
#   inflating: test/2426.jpg
#   inflating: test/0398.jpg
#   inflating: test/2305.jpg
#   inflating: test/2462.jpg
#   inflating: test/1212.jpg
#   inflating: test/0545.jpg
#   inflating: test/2040.jpg
#   inflating: test/0294.jpg
#   inflating: test/1648.jpg
#   inflating: test/1283.jpg
#   inflating: test/0522.jpg
#   inflating: test/0467.jpg
#   inflating: test/0221.jpg
#   inflating: test/1929.jpg
#   inflating: test/2402.jpg
#   inflating: test/0190.jpg
#   inflating: test/2122.jpg
#   inflating: test/2555.jpg
#   inflating: test/1162.jpg
#   inflating: test/0967.jpg
#   inflating: test/0345.jpg
#   inflating: test/0097.jpg
#   inflating: test/2955.jpg
#   inflating: test/0405.jpg
#   inflating: test/2119.jpg
#   inflating: test/2079.jpg
#   inflating: test/2138.jpg
#   inflating: test/1577.jpg
#   inflating: test/1905.jpg
#   inflating: test/2618.jpg
#   inflating: test/1645.jpg
#   inflating: test/0968.jpg
#   inflating: test/0197.jpg
#   inflating: test/1471.jpg
#   inflating: test/0755.jpg
#   inflating: test/2229.jpg
#   inflating: test/1702.jpg
#   inflating: test/1172.jpg
#   inflating: test/0831.jpg
#   inflating: test/0044.jpg
#   inflating: test/1293.jpg
#   inflating: test/0668.jpg
#   inflating: test/1271.jpg
#   inflating: test/0220.jpg
#   inflating: test/0695.jpg
#   inflating: test/2567.jpg
#   inflating: test/0451.jpg
#   inflating: test/1731.jpg
#   inflating: test/0155.jpg
#   inflating: test/0144.jpg
#   inflating: test/1406.jpg
#   inflating: test/1714.jpg
#   inflating: test/2740.jpg
#   inflating: test/0480.jpg
#   inflating: test/1886.jpg
#   inflating: test/0487.jpg
#   inflating: test/1150.jpg
#   inflating: test/2763.jpg
#   inflating: test/0822.jpg
#   inflating: test/2220.jpg
#   inflating: test/1179.jpg
#   inflating: test/0117.jpg
#   inflating: test/2394.jpg
#   inflating: test/2276.jpg
#   inflating: test/0439.jpg
#   inflating: test/1633.jpg
#   inflating: test/2533.jpg
#   inflating: test/0383.jpg
#   inflating: test/1594.jpg
#   inflating: test/1277.jpg
#   inflating: test/2526.jpg
#   inflating: test/2624.jpg
#   inflating: test/0888.jpg
#   inflating: test/2784.jpg
#   inflating: test/2807.jpg
#   inflating: test/0972.jpg
#   inflating: test/1055.jpg
#   inflating: test/1942.jpg
#   inflating: test/0079.jpg
#   inflating: test/2549.jpg
#   inflating: test/1417.jpg
#   inflating: test/1130.jpg
#   inflating: test/2916.jpg
#   inflating: test/1769.jpg
#   inflating: test/2793.jpg
#   inflating: test/1020.jpg
#   inflating: test/0299.jpg
#   inflating: test/0640.jpg
#   inflating: test/0068.jpg
#   inflating: test/1681.jpg
#   inflating: test/0995.jpg
#   inflating: test/1351.jpg
#   inflating: test/1514.jpg
#   inflating: test/2216.jpg
#   inflating: test/0394.jpg
#   inflating: test/1609.jpg
#   inflating: test/2746.jpg
#   inflating: test/2425.jpg
#   inflating: test/1289.jpg
#   inflating: test/1669.jpg
#   inflating: test/0445.jpg
#   inflating: test/0287.jpg
#   inflating: test/0258.jpg
#   inflating: test/1045.jpg
#   inflating: test/0063.jpg
#   inflating: test/2250.jpg
#   inflating: test/2133.jpg
#   inflating: test/0375.jpg
#   inflating: test/0973.jpg
#   inflating: test/2877.jpg
#   inflating: test/2743.jpg
#   inflating: test/1655.jpg
#   inflating: test/2714.jpg
#   inflating: test/0194.jpg
#   inflating: test/2543.jpg
#   inflating: test/1981.jpg
#   inflating: test/0432.jpg
#   inflating: test/1618.jpg
#   inflating: test/0950.jpg
#   inflating: test/0653.jpg
#   inflating: test/0701.jpg
#   inflating: test/2453.jpg
#   inflating: test/2613.jpg
#   inflating: test/0797.jpg
#   inflating: test/1615.jpg
#   inflating: test/1979.jpg
#   inflating: test/0651.jpg
#   inflating: test/2705.jpg
#   inflating: test/2128.jpg
#   inflating: test/1501.jpg
#   inflating: test/0473.jpg
#   inflating: test/0669.jpg
#   inflating: test/2202.jpg
#   inflating: test/1850.jpg
#   inflating: test/2588.jpg
#   inflating: test/2368.jpg
#   inflating: test/2016.jpg
#   inflating: test/2289.jpg
#   inflating: test/1579.jpg
#   inflating: test/2634.jpg
#   inflating: test/2052.jpg
#   inflating: test/2390.jpg
#   inflating: test/1117.jpg
#   inflating: test/2005.jpg
#   inflating: test/2669.jpg
#   inflating: test/2259.jpg
#   inflating: test/1634.jpg
#   inflating: test/1104.jpg
#   inflating: test/0939.jpg
#   inflating: test/0340.jpg
#   inflating: test/2947.jpg
#   inflating: test/0341.jpg
#   inflating: test/2341.jpg
#   inflating: test/1030.jpg
#   inflating: test/1919.jpg
#   inflating: test/2400.jpg
#   inflating: test/1201.jpg
#   inflating: test/2602.jpg
#   inflating: test/2077.jpg
#   inflating: test/1574.jpg
#   inflating: test/1464.jpg
#   inflating: test/1696.jpg
#   inflating: test/1169.jpg
#   inflating: test/0214.jpg
#   inflating: test/1113.jpg
#   inflating: test/1605.jpg
#   inflating: test/0367.jpg
#   inflating: test/0542.jpg
#   inflating: test/1749.jpg
#   inflating: test/1583.jpg
#   inflating: test/0994.jpg
#   inflating: test/2424.jpg
#   inflating: test/2420.jpg
#   inflating: test/1991.jpg
#   inflating: test/2231.jpg
#   inflating: test/1484.jpg
#   inflating: test/2373.jpg
#   inflating: test/2592.jpg
#   inflating: test/0770.jpg
#   inflating: test/0801.jpg
#   inflating: test/2244.jpg
#   inflating: test/1795.jpg
#   inflating: test/2735.jpg
#   inflating: test/2732.jpg
#   inflating: test/2563.jpg
#   inflating: test/1927.jpg
#   inflating: test/2242.jpg
#   inflating: test/0316.jpg
#   inflating: test/0421.jpg
#   inflating: test/0510.jpg
#   inflating: test/1295.jpg
#   inflating: test/0122.jpg
#   inflating: test/1895.jpg
#   inflating: test/1599.jpg
#   inflating: test/0687.jpg
#   inflating: test/2918.jpg
#   inflating: test/1082.jpg
#   inflating: test/1688.jpg
#   inflating: test/1414.jpg
#   inflating: test/1336.jpg
#   inflating: test/0840.jpg
#   inflating: test/0987.jpg
#   inflating: test/1745.jpg
#   inflating: test/0656.jpg
#   inflating: test/1974.jpg
#   inflating: test/2696.jpg
#   inflating: test/1272.jpg
#   inflating: test/0759.jpg
#   inflating: test/1873.jpg
#   inflating: test/0521.jpg
#   inflating: test/1348.jpg
#   inflating: test/2723.jpg
#   inflating: test/2127.jpg
#   inflating: test/1500.jpg
#   inflating: test/1015.jpg
#   inflating: test/0941.jpg
#   inflating: test/0908.jpg
#   inflating: test/0777.jpg
#   inflating: test/1698.jpg
#   inflating: test/1255.jpg
#   inflating: test/1862.jpg
#   inflating: test/2051.jpg
#   inflating: test/2075.jpg
#   inflating: test/1371.jpg
#   inflating: test/2304.jpg
#   inflating: test/0789.jpg
#   inflating: test/2600.jpg
#   inflating: test/0626.jpg
#   inflating: test/1221.jpg
#   inflating: test/0624.jpg
#   inflating: test/1208.jpg
#   inflating: test/1595.jpg
#   inflating: test/2622.jpg
#   inflating: test/0219.jpg
#   inflating: test/0576.jpg

# %% [markdown]
# # Import Packages

# %%
_exp_name = "0317esm"

# %%
# Import necessary packages.
import numpy as np
import pandas as pd
import torch
import os
import torch.nn as nn
import torchvision.transforms as transforms
from PIL import Image
# "ConcatDataset" and "Subset" are possibly useful when doing semi-supervised learning.
from torch.utils.data import ConcatDataset, DataLoader, Subset, Dataset
from torchvision.datasets import DatasetFolder, VisionDataset
# This is for the progress bar.
from tqdm.auto import tqdm
import random

# %%
myseed = 42  # set a random seed for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %% [markdown]
# # Transforms
# Torchvision provides lots of useful utilities for image preprocessing, data *wrapping* as well as data augmentation.
#
# Please refer to PyTorch official website for details about different transforms.

# %%
# Normally, We don't need augmentations in testing and validation.
# All we need here is to resize the PIL image and transform it into Tensor.
test_tfm = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
])

valid_tfm = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
])

# However, it is also possible to use augmentation in the testing phase.
# You may use train_tfm to produce a variety of images and then test using ensemble methods
train_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    transforms.Resize((128, 128)),
    # You may add some transforms here.
    transforms.RandomHorizontalFlip(p=0.3),
    transforms.RandomVerticalFlip(p=0.3),
    transforms.RandomRotation(45),
    transforms.RandomGrayscale(p=0.1),
    # ToTensor() should be the last one of the transforms.
    transforms.ToTensor(),
])

# %% [markdown]
# # Datasets
# The data is labelled by the name, so we load images and label while calling '__getitem__'

# %%
class FoodDataset2(Dataset):

    def __init__(self,path1,path2,split,mode = ''):
        super(FoodDataset2).__init__()
        list1 = [os.path.join(path1,x) for x in os.listdir(path1) if x.endswith(".jpg")]
        list2 = [os.path.join(path2,x) for x in os.listdir(path2) if x.endswith(".jpg")]
        f_list = sorted(list1+list2)
        random.seed(42)
        random.shuffle(f_list)
        self.mode = mode
        self.split = split
            
        if mode == 'train':  
            list00 = []
            for i in range (10231):
                list00.append(i)
            random.shuffle(list00)
            self.reflist = list00
            
            if split == 0:
                self.files = f_list[3412:]
            elif split == 1:
                self.files = f_list[:3412]+f_list[6824:]
            elif split == 2:
                self.files = f_list[:6824]+f_list[10236:]
            elif split == 3:
                self.files = f_list[:10236]
                
            self.transform = train_tfm
        elif mode == 'valid':  

            if split == 0:
                self.files = f_list[:3412]
            elif split == 1:
                self.files = f_list[3412:6824]
            elif split == 2:
                self.files = f_list[6824:10236]
            elif split == 3:
                self.files = f_list[10236:]
                
            self.transform = valid_tfm

  
    def __len__(self):
        return len(self.files)
  
    def __getitem__(self,idx):
        fname = self.files[idx]
        im = Image.open(fname)
        
        if self.mode == 'train':
            if idx%4 == self.split:
                im = test_tfm(im)

                label = int(fname.split("/")[-1].split("_")[0])
                #get mixup img
                fname = self.files[self.reflist[idx%10231]]
                im_mix = Image.open(fname)
                im_mix = test_tfm(im_mix)
                label_mix = int(fname.split("/")[-1].split("_")[0])
                #do mixup
                im2 = 0.7*im + 0.3*im_mix
                label_list = torch.zeros(13)
                label_list[label] += 0.7
                label_list[label_mix] += 0.3
                label_list[11] = label
                label_list[12] = label_mix

                return im2,label_list
            else:
                im = self.transform(im)

                label = int(fname.split("/")[-1].split("_")[0])

                #Label smoothing
                label_list = torch.zeros(13)
                for i in range(11):
                    label_list[i] = 0.1
                label_list[label] = 0.9
                label_list[11] = label
                label_list[12] = label
                
                return im,label_list
        else:
            im = self.transform(im)

            label = int(fname.split("/")[-1].split("_")[0])
            
            #Label smoothing
            label_list = torch.zeros(12)
            for i in range(11):
                    label_list[i] = 0.1
            label_list[label] = 0.9
            label_list[11] = label
            
            return im,label_list

# %%
class FoodDataset(Dataset):

    def __init__(self,path,tfm=test_tfm,files = None, mode = ''):
        super(FoodDataset).__init__()
        self.path = path
        self.files = sorted([os.path.join(path,x) for x in os.listdir(path) if x.endswith(".jpg")])
        self.mode = mode
  
    def __len__(self):
        return len(self.files)
  
    def __getitem__(self,idx):
        fname = self.files[idx]
        im = Image.open(fname)
        
        if self.mode == 'test':
            ims = [test_tfm(im)]
            ims += [train_tfm(im) for _ in range(10)]
            label = -1 # test has no label
            return torch.stack(ims), label

# %% [markdown]
# # Model

# %%
class Residual_Block(nn.Module):
    def __init__(self, i_channel, o_channel, stride=1, down_sample=None):
        super(Residual_Block, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=i_channel, 
                    out_channels=o_channel, 
                    kernel_size=3, 
                    stride=stride, 
                    padding=1,
                    bias=False)
        self.bn1 = nn.BatchNorm2d(o_channel)
        self.relu = nn.LeakyReLU(0.1)
        self.conv2 = nn.Conv2d(in_channels=o_channel, 
                    out_channels=o_channel, 
                    kernel_size=3, 
                    stride=1, 
                    padding=1,
                    bias=False)
        self.bn2 = nn.BatchNorm2d(o_channel)
        self.down_sample = down_sample

    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        
        if self.down_sample:
            residual = self.down_sample(x)
        out += residual
        out = self.relu(out)

        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, layers, num_classes=11):
        super(ResNet, self).__init__()
        self.conv = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1, bias=False)
        self.in_channels = 16
        self.bn = nn.BatchNorm2d(16)
        self.relu1 = nn.LeakyReLU(0.1)
        self.layer1 = self.make_layer(block, 16, layers[0])
        self.layer2 = self.make_layer(block, 32, layers[0], 2)
        self.layer3 = self.make_layer(block, 64, layers[1], 2)
        self.avg_pool = nn.AvgPool2d(8)
        self.fc1 = nn.Linear(1024, 256)
        self.relu2 = nn.LeakyReLU(0.1)
        self.dropout = nn.Dropout(p=0.2)
        self.fc2 = nn.Linear(256, num_classes)
        
    def make_layer(self, block, out_channels, blocks, stride=1):  
        down_sample = None
        if (stride != 1) or (self.in_channels != out_channels):
            down_sample = nn.Sequential(
                nn.Conv2d(self.in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
                nn.BatchNorm2d(out_channels)
            )

        layers = []
        layers.append(block(self.in_channels, out_channels, stride, down_sample))
        self.in_channels = out_channels
        for i in range(1, blocks):
            layers.append(block(out_channels, out_channels))
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv(x)
        out = self.bn(out)
        out = self.relu1(out)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.avg_pool(out)
        out = out.view(out.size()[0], -1)
        out = self.fc1(out)
        out = self.relu2(out)
        out = self.dropout(out)
        out = self.fc2(out)
        '''
        if torch.isnan(out)[0][0]:
            print('nan',x)'''
        return out

# %% [markdown]
# # Configurations

# %%
# "cuda" only when GPUs are available.
device = "cuda" if torch.cuda.is_available() else "cpu"

# Initialize a model, and put it on the device specified.
model = ResNet(Residual_Block, [2, 2, 2, 2]).to(device)

# The number of batch size.
batch_size = 64

# The number of training epochs.
n_epochs = 210

# If no improvement in 'patience' epochs, early stop.
patience = 210

# For the classification task, we use cross-entropy as the measurement of performance.
#criterion = nn.CrossEntropyLoss()

# Initialize optimizer, you may fine-tune some hyperparameters such as learning rate on your own.
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer,T_0=30,T_mult=2)

# %% [markdown]
# # Dataloader

# %%
# Construct train and valid datasets.
# The argument "loader" tells how torchvision reads the data.
k_fold_split = 2
train_set = FoodDataset2("./train","./valid",split = k_fold_split, mode='train')
valid_set = FoodDataset2("./train","./valid",split = k_fold_split, mode='valid')

print("train_set:",len(train_set.files),"valid_set:",len(valid_set.files))

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)
# Out:
# train_set: 10231 valid_set: 3412

# %% [markdown]
# # Class-balanced focal loss

# %%
import torch.nn.functional as F

def focal_loss(logits, labels, alpha, gamma):
    
    bce_loss = F.binary_cross_entropy_with_logits(input=logits, target=labels, reduction="none")
    
    t0 = torch.zeros(2,logits.shape[0],11).to(device)
    t0[0] = -1.0 * logits
    
    f1 = torch. logsumexp(t0, dim=0)
    f2 = - gamma * f1
    f3 = -gamma * labels * logits

    modulator = torch.exp(f3 + f2)
    modulator = torch.nan_to_num(modulator, nan=1)
    
    loss = modulator * bce_loss
    
    weighted_loss = alpha * loss
    loss = torch.sum(weighted_loss)
    loss /= torch.sum(labels)
    
    #print((loss))
    '''
    nploss = loss.cpu().detach().numpy()
    if np.isnan(nploss):
        print(logits, labels)'''
        
    #print((loss))
    
    return loss

# %%
class ClassBalancedLoss(torch.nn.Module):
    def __init__(self, samples_per_class=None, beta=0.9999, gamma=0.5):
        super(ClassBalancedLoss, self).__init__()

        effective_num = 1.0 - np.power(beta, samples_per_class)
        weights = (1.0 - beta) / np.array(effective_num)
        self.constant_sum = len(samples_per_class)
        weights = (weights / np.sum(weights) * self.constant_sum).astype(np.float32)
        self.class_weights = weights
        self.gamma = gamma


    def forward(self, x, y):

        _, num_classes = x.shape
        labels_one_hot = y.argmax(dim=-1)
        weights = torch.tensor(self.class_weights, device=x.device).index_select(0, y.argmax(dim=-1))
        weights = weights.unsqueeze(1)
        cb_loss = focal_loss(x, y, weights, self.gamma)

        return cb_loss

# %%
f_len = len(train_set.files)
samples_per_class = []

for i in range(11):
    samples_per_class.append(0)

for i in range (f_len):
    fname = train_set.files[i]
    label = int(fname.split("/")[-1].split("_")[0])
    samples_per_class[label] += 1
    
print("samples_per_class:", samples_per_class)

criterion = ClassBalancedLoss(samples_per_class=samples_per_class)
# Out:
# samples_per_class: [1016, 1540, 448, 1371, 282, 450, 883, 1546, 717, 1063, 915]

# %% [markdown]
# # Start Training

# %%
# Initialize trackers, these are not parameters and should not be changed
stale = 0
best_acc = 0
best_loss = 5


for epoch in range(n_epochs):

    # ---------- Training ----------
    # Make sure the model is in train mode before training.
    model.train()

    # These are used to record information in training.
    train_loss = []
    train_accs = []

    for batch in tqdm(train_loader):

        # A batch consists of image data and corresponding labels.
        imgs, labels = batch
        #imgs = imgs.half()
        #print(imgs)

        # Forward the data. (Make sure data and model are on the same device.)
        logits = model(imgs.to(device))
        #print(logits, labels)


        # Calculate the cross-entropy loss.
        # We don't need to apply softmax before computing cross-entropy as it is done automatically.
            
        loss = criterion(logits, labels[:,:11].to(device))

        # Gradients stored in the parameters in the previous step should be cleared out first.
        optimizer.zero_grad()
        
        if not torch.isnan(loss):
            # Compute the gradients for parameters.
            loss.backward()

            # Clip the gradient norms for stable training.
            grad_norm = nn.utils.clip_grad_norm_(model.parameters(), max_norm=10)

            # Update the parameters with computed gradients.
            optimizer.step()

        # Compute the accuracy for current batch.
        label_1_acc = (logits.argmax(dim=-1) == labels[:,11].to(device)).float().mean()
        label_2_acc = (logits.argmax(dim=-1) == labels[:,12].to(device)).float().mean()
        acc = 0.7*label_1_acc + 0.3*label_2_acc

        # Record the loss and accuracy.
        train_loss.append(loss.item())
        train_accs.append(acc)
        
    train_loss = sum(train_loss) / len(train_loss)
    train_acc = sum(train_accs) / len(train_accs)
    
    
    # Print the information.
    print(f"[ Train | {epoch + 1:03d}/{n_epochs:03d} ] loss = {train_loss:.5f}, acc = {train_acc:.5f}")
    scheduler.step()
    # ---------- Validation ----------
    # Make sure the model is in eval mode so that some modules like dropout are disabled and work normally.
    model.eval()

    # These are used to record information in validation.
    valid_loss = []
    valid_accs = []

    # Iterate the validation set by batches.
    for batch in tqdm(valid_loader):

        # A batch consists of image data and corresponding labels.
        imgs, labels = batch
        #imgs = imgs.half()

        # We don't need gradient in validation.
        # Using torch.no_grad() accelerates the forward process.
        with torch.no_grad():
            logits = model(imgs.to(device))

        # We can still compute the loss (but not the gradient).
        loss = criterion(logits, labels[:,:11].to(device))

        # Compute the accuracy for current batch.
        acc = (logits.argmax(dim=-1) == labels[:,11].to(device)).float().mean()

        # Record the loss and accuracy.
        valid_loss.append(loss.item())
        valid_accs.append(acc)
        #break

    # The average loss and accuracy for entire validation set is the average of the recorded values.
    valid_loss = sum(valid_loss) / len(valid_loss)
    valid_acc = sum(valid_accs) / len(valid_accs)

    # Print the information.
    #print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {valid_loss:.5f}, acc = {valid_acc:.5f}")


    # update logs
    if valid_acc > best_acc:
        with open(f"./{_exp_name}_log.txt","a"):
            print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {valid_loss:.5f}, acc = {valid_acc:.5f} -> best acc")
    else:
        with open(f"./{_exp_name}_log.txt","a"):
            print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {valid_loss:.5f}, acc = {valid_acc:.5f}")


    # save models
    if valid_acc > best_acc:
        print(f"Best acc model found at epoch {epoch}, saving model")
        torch.save(model.state_dict(), f"{_exp_name}_best.ckpt") # only save best to prevent output memory exceed error
        best_acc = valid_acc
        stale = 0
    else:
        stale += 1
        if stale > patience:
            print(f"No improvment {patience} consecutive epochs, early stopping")
            break
    
    #for label smoothing
    if valid_loss < best_loss:
        with open(f"./{_exp_name}_log.txt","a"):
            print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {valid_loss:.5f}, acc = {valid_acc:.5f} -> best loss")
        print(f"Best loss model found at epoch {epoch}, saving model")
        torch.save(model.state_dict(), f"{_exp_name}_best_loss.ckpt") # only save best to prevent output memory exceed error
        best_loss = valid_loss
# Out:
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 001/250 ] loss = 1.71099, acc = 0.17693
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 001/250 ] loss = 1.60942, acc = 0.26226 -> best acc
# Best acc model found at epoch 0, saving model
# [ Valid | 001/250 ] loss = 1.60942, acc = 0.26226 -> best loss
# Best loss model found at epoch 0, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 002/250 ] loss = 1.51024, acc = 0.25899
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 002/250 ] loss = 1.60143, acc = 0.31228 -> best acc
# Best acc model found at epoch 1, saving model
# [ Valid | 002/250 ] loss = 1.60143, acc = 0.31228 -> best loss
# Best loss model found at epoch 1, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 003/250 ] loss = 1.44611, acc = 0.29581
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 003/250 ] loss = 1.53760, acc = 0.35687 -> best acc
# Best acc model found at epoch 2, saving model
# [ Valid | 003/250 ] loss = 1.53760, acc = 0.35687 -> best loss
# Best loss model found at epoch 2, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 004/250 ] loss = 1.38865, acc = 0.33684
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 004/250 ] loss = 1.59257, acc = 0.27316
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 005/250 ] loss = 1.34900, acc = 0.35986
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 005/250 ] loss = 1.36447, acc = 0.40551 -> best acc
# Best acc model found at epoch 4, saving model
# [ Valid | 005/250 ] loss = 1.36447, acc = 0.40551 -> best loss
# Best loss model found at epoch 4, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 006/250 ] loss = 1.31127, acc = 0.36906
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 006/250 ] loss = 1.34031, acc = 0.43338 -> best acc
# Best acc model found at epoch 5, saving model
# [ Valid | 006/250 ] loss = 1.34031, acc = 0.43338 -> best loss
# Best loss model found at epoch 5, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 007/250 ] loss = 1.27885, acc = 0.39484
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 007/250 ] loss = 1.40910, acc = 0.39563
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 008/250 ] loss = 1.25180, acc = 0.41332
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 008/250 ] loss = 1.28730, acc = 0.47831 -> best acc
# Best acc model found at epoch 7, saving model
# [ Valid | 008/250 ] loss = 1.28730, acc = 0.47831 -> best loss
# Best loss model found at epoch 7, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 009/250 ] loss = 1.22202, acc = 0.42265
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 009/250 ] loss = 1.28028, acc = 0.45370
# [ Valid | 009/250 ] loss = 1.28028, acc = 0.45370 -> best loss
# Best loss model found at epoch 8, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 010/250 ] loss = 1.19537, acc = 0.44615
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 010/250 ] loss = 1.71896, acc = 0.33537
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 011/250 ] loss = 1.16735, acc = 0.46098
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 011/250 ] loss = 1.28060, acc = 0.49742 -> best acc
# Best acc model found at epoch 10, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 012/250 ] loss = 1.16024, acc = 0.46114
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 012/250 ] loss = 1.15723, acc = 0.51980 -> best acc
# Best acc model found at epoch 11, saving model
# [ Valid | 012/250 ] loss = 1.15723, acc = 0.51980 -> best loss
# Best loss model found at epoch 11, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 013/250 ] loss = 1.12403, acc = 0.48274
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 013/250 ] loss = 1.29005, acc = 0.46482
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 014/250 ] loss = 1.10139, acc = 0.48616
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 014/250 ] loss = 1.38466, acc = 0.48942
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 015/250 ] loss = 1.08223, acc = 0.49750
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 015/250 ] loss = 1.27671, acc = 0.51535
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 016/250 ] loss = 1.05940, acc = 0.51136
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 016/250 ] loss = 1.27684, acc = 0.49146
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 017/250 ] loss = 1.04564, acc = 0.51076
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 017/250 ] loss = 1.37730, acc = 0.47567
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 018/250 ] loss = 1.02920, acc = 0.52549
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 018/250 ] loss = 1.16377, acc = 0.51331
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 019/250 ] loss = 1.00305, acc = 0.52975
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 019/250 ] loss = 1.03775, acc = 0.58291 -> best acc
# Best acc model found at epoch 18, saving model
# [ Valid | 019/250 ] loss = 1.03775, acc = 0.58291 -> best loss
# Best loss model found at epoch 18, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 020/250 ] loss = 0.98226, acc = 0.54039
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 020/250 ] loss = 1.45044, acc = 0.49379
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 021/250 ] loss = 0.97787, acc = 0.53870
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 021/250 ] loss = 1.17506, acc = 0.52347
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 022/250 ] loss = 0.95708, acc = 0.55265
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 022/250 ] loss = 0.95006, acc = 0.62562 -> best acc
# Best acc model found at epoch 21, saving model
# [ Valid | 022/250 ] loss = 0.95006, acc = 0.62562 -> best loss
# Best loss model found at epoch 21, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 023/250 ] loss = 0.93675, acc = 0.56276
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 023/250 ] loss = 1.00345, acc = 0.58168
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 024/250 ] loss = 0.93195, acc = 0.55997
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 024/250 ] loss = 1.03064, acc = 0.59338
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 025/250 ] loss = 0.91970, acc = 0.56885
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 025/250 ] loss = 1.21259, acc = 0.53690
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 026/250 ] loss = 0.89278, acc = 0.57791
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 026/250 ] loss = 0.97709, acc = 0.60641
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 027/250 ] loss = 0.90224, acc = 0.57740
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 027/250 ] loss = 0.88039, acc = 0.65287 -> best acc
# Best acc model found at epoch 26, saving model
# [ Valid | 027/250 ] loss = 0.88039, acc = 0.65287 -> best loss
# Best loss model found at epoch 26, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 028/250 ] loss = 0.87337, acc = 0.59115
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 028/250 ] loss = 1.09618, acc = 0.60393
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 029/250 ] loss = 0.88220, acc = 0.58758
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 029/250 ] loss = 1.09976, acc = 0.57052
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 030/250 ] loss = 0.85666, acc = 0.59767
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 030/250 ] loss = 1.14808, acc = 0.59538
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 031/250 ] loss = 0.84975, acc = 0.59604
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 031/250 ] loss = 1.02644, acc = 0.62944
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 032/250 ] loss = 0.84442, acc = 0.60783
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 032/250 ] loss = 1.11582, acc = 0.56763
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 033/250 ] loss = 0.81823, acc = 0.61722
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 033/250 ] loss = 0.90987, acc = 0.63363
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 034/250 ] loss = 0.81607, acc = 0.61537
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 034/250 ] loss = 1.04251, acc = 0.62767
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 035/250 ] loss = 0.80077, acc = 0.62350
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 035/250 ] loss = 0.98377, acc = 0.66605 -> best acc
# Best acc model found at epoch 34, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 036/250 ] loss = 0.79521, acc = 0.62635
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 036/250 ] loss = 0.93941, acc = 0.66649 -> best acc
# Best acc model found at epoch 35, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 037/250 ] loss = 0.78743, acc = 0.63114
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 037/250 ] loss = 0.94731, acc = 0.64433
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 038/250 ] loss = 0.78555, acc = 0.62955
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 038/250 ] loss = 0.88943, acc = 0.64689
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 039/250 ] loss = 0.78068, acc = 0.63561
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 039/250 ] loss = 0.97109, acc = 0.67332 -> best acc
# Best acc model found at epoch 38, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 040/250 ] loss = 0.77183, acc = 0.63725
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 040/250 ] loss = 1.06544, acc = 0.63724
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 041/250 ] loss = 0.75650, acc = 0.64692
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 041/250 ] loss = 2.50513, acc = 0.41981
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 042/250 ] loss = 0.74893, acc = 0.64533
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 042/250 ] loss = 1.22012, acc = 0.60425
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 043/250 ] loss = 0.74369, acc = 0.64664
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 043/250 ] loss = 1.01796, acc = 0.65314
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 044/250 ] loss = 0.73244, acc = 0.64931
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 044/250 ] loss = 1.11043, acc = 0.61943
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 045/250 ] loss = 0.73221, acc = 0.65433
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 045/250 ] loss = 1.45892, acc = 0.58572
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 046/250 ] loss = 0.72494, acc = 0.65788
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 046/250 ] loss = 0.91427, acc = 0.67312
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 047/250 ] loss = 0.71855, acc = 0.65608
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 047/250 ] loss = 0.86131, acc = 0.69479 -> best acc
# Best acc model found at epoch 46, saving model
# [ Valid | 047/250 ] loss = 0.86131, acc = 0.69479 -> best loss
# Best loss model found at epoch 46, saving model
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 048/250 ] loss = 0.69204, acc = 0.67060
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 048/250 ] loss = 1.01853, acc = 0.67339
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 049/250 ] loss = 0.71385, acc = 0.66282
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 049/250 ] loss = 0.89934, acc = 0.68979
#   0%|          | 0/80 [00:00<?, ?it/s]
# [ Train | 050/250 ] loss = 0.68727, acc = 0.67475
#   0%|          | 0/27 [00:00<?, ?it/s]
# [ Valid | 050/250 ] loss = 1.18930, acc = 0.61890
#   0%|          | 0/80 [00:00<?, ?it/s]

# %% [markdown]
# # Dataloader for test

# %%
# Construct test datasets.
# The argument "loader" tells how torchvision reads the data.
test_set = FoodDataset("./test", tfm=test_tfm, mode = 'test')
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

# %% [markdown]
# # Testing and generate prediction CSV

# %%
model_best = ResNet(Residual_Block, [2, 2, 2, 2]).to(device)
model_best1 = ResNet(Residual_Block, [2, 2, 2, 2]).to(device)
model_best2 = ResNet(Residual_Block, [2, 2, 2, 2]).to(device)
model_best3 = ResNet(Residual_Block, [2, 2, 2, 2]).to(device)
model_best.load_state_dict(torch.load(f"/content/0316kf0_best.ckpt"))
model_best1.load_state_dict(torch.load(f"/content/0315kf1_best.ckpt"))
model_best2.load_state_dict(torch.load(f"/content/0317kf2_best.ckpt"))
model_best3.load_state_dict(torch.load(f"/content/0317kf3_best.ckpt"))
model_best.eval()
model_best1.eval()
model_best2.eval()
model_best3.eval()
test_pred1 = []
test_pred2 = []
test_pred3 = []
test_pred4 = []
prediction = []
with torch.no_grad():
    for data,_ in tqdm(test_loader):
        test_pred1 = []
        # TTA
        for imgs in data:
            imgs_first = imgs[0].unsqueeze(0)
            origin_logit = model_best(imgs_first.to(device)).squeeze(0)
            tta_logit = model_best(imgs[1:].to(device))
            tta_logit = torch.mean(tta_logit, 0)
            logit = (0.6*origin_logit) + (0.4*tta_logit)
            test_pred1.append(logit)
            
        test_pred1 = torch.stack(test_pred1).cpu().data.numpy()

        test_pred2 = []
        for imgs in data:
            imgs_first = imgs[0].unsqueeze(0)
            origin_logit = model_best1(imgs_first.to(device)).squeeze(0)
            tta_logit = model_best1(imgs[1:].to(device))
            tta_logit = torch.mean(tta_logit, 0)
            logit = (0.6*origin_logit) + (0.4*tta_logit)
            test_pred2.append(logit)
            
        test_pred2 = torch.stack(test_pred2).cpu().data.numpy()

        test_pred3 = []
        for imgs in data:
            imgs_first = imgs[0].unsqueeze(0)
            origin_logit = model_best2(imgs_first.to(device)).squeeze(0)
            tta_logit = model_best2(imgs[1:].to(device))
            tta_logit = torch.mean(tta_logit, 0)
            logit = (0.6*origin_logit) + (0.4*tta_logit)
            test_pred3.append(logit)
            
        test_pred3 = torch.stack(test_pred3).cpu().data.numpy()

        test_pred4 = []
        for imgs in data:
            imgs_first = imgs[0].unsqueeze(0)
            origin_logit = model_best3(imgs_first.to(device)).squeeze(0)
            tta_logit = model_best3(imgs[1:].to(device))
            tta_logit = torch.mean(tta_logit, 0)
            logit = (0.6*origin_logit) + (0.4*tta_logit)
            test_pred4.append(logit)
            
        test_pred4 = torch.stack(test_pred4).cpu().data.numpy()
        
        test_label = np.argmax(test_pred1+test_pred2+test_pred3+test_pred4, axis=1)
        prediction += test_label.squeeze().tolist()
# Out:
#   0%|          | 0/47 [00:00<?, ?it/s]

# %%
model_best = ResNet(Residual_Block, [2, 2, 2, 2]).to(device)
model_best1 = ResNet(Residual_Block, [2, 2, 2, 2]).to(device)
model_best.load_state_dict(torch.load(f"/content/0317kf2_best.ckpt"))
model_best1.load_state_dict(torch.load(f"/content/0317kf3_best.ckpt"))
model_best.eval()
model_best1.eval()
test_pred1 = []
test_pred2 = []
prediction = []
with torch.no_grad():
    for data,_ in tqdm(test_loader):
        test_pred1 = []
        # TTA
        for imgs in data:
            imgs_first = imgs[0].unsqueeze(0)
            origin_logit = model_best(imgs_first.to(device)).squeeze(0)
            tta_logit = model_best(imgs[1:].to(device))
            tta_logit = torch.mean(tta_logit, 0)
            logit = (0.6*origin_logit) + (0.4*tta_logit)
            test_pred1.append(logit)
            
        test_pred1 = torch.stack(test_pred1).cpu().data.numpy()

        test_pred2 = []
        for imgs in data:
            imgs_first = imgs[0].unsqueeze(0)
            origin_logit = model_best1(imgs_first.to(device)).squeeze(0)
            tta_logit = model_best1(imgs[1:].to(device))
            tta_logit = torch.mean(tta_logit, 0)
            logit = (0.6*origin_logit) + (0.4*tta_logit)
            test_pred2.append(logit)
            
        test_pred2 = torch.stack(test_pred2).cpu().data.numpy()


        
        test_label = np.argmax(test_pred1+test_pred2, axis=1)
        prediction += test_label.squeeze().tolist()
# Out:
#   0%|          | 0/47 [00:00<?, ?it/s]

# %%
# create test csv
def pad4(i):
    return "0"*(4-len(str(i)))+str(i)
df = pd.DataFrame()
df["Id"] = [pad4(i) for i in range(len(test_set))]
df["Category"] = prediction
df.to_csv("submission.csv",index = False)

# %%
from google.colab import files
files.download('submission.csv')

# %% [markdown]
# ### Label smoothing

# %%
model_best = ResNet(Residual_Block, [2, 2, 2, 2]).to(device)
model_best.load_state_dict(torch.load(f"/content/0317kf3_best.ckpt"))
model_best.eval()
prediction = []
with torch.no_grad():
    for data,_ in tqdm(test_loader):
        
        # TTA
        test_pred = []
        for imgs in data:
            imgs_first = imgs[0].unsqueeze(0)
            origin_logit = model_best(imgs_first.to(device)).squeeze(0)
            tta_logit = model_best(imgs[1:].to(device))
            tta_logit = torch.mean(tta_logit, 0)
            logit = (0.6*origin_logit) + (0.4*tta_logit)
            test_pred.append(logit)
            
        test_pred = torch.stack(test_pred)
        
        test_label = np.argmax(test_pred.cpu().data.numpy(), axis=1)
        prediction += test_label.squeeze().tolist()
# Out:
#   0%|          | 0/47 [00:00<?, ?it/s]

# %%
#create test csv
def pad4(i):
    return "0"*(4-len(str(i)))+str(i)
df = pd.DataFrame()
df["Id"] = [pad4(i) for i in range(len(test_set))]
df["Category"] = prediction
df.to_csv("submission_LB.csv",index = False)

# %%
from google.colab import files
files.download('submission_LB.csv')

# %% [markdown]
# # Voting

# %%
from collections import Counter
import csv

with open(f"/content/submission_0317kf2.csv", newline='') as f:
  reader = csv.reader(f)
  content1 = []
  for row in reader:
    content1.append(row[1])
  content1 = content1[1:]
with open(f"/content/submission_0317kf3.csv", newline='') as f:
  reader = csv.reader(f)
  content2 = []
  for row in reader:
    content2.append(row[1])
  content2 = content2[1:]
with open(f"/content/submission.csv", newline='') as f:
  reader = csv.reader(f)
  content3 = []
  for row in reader:
    content3.append(row[1])
  content3 = content3[1:]
with open(f"/content/0313v1.csv", newline='') as f:
  reader = csv.reader(f)
  content4 = []
  for row in reader:
    content4.append(row[1])
  content4 = content4[1:]

prediction = []
for i in range(len(test_set)):
  x = Counter([content4[i], content1[i], content2[i], content3[i]])
  prediction.append(x.most_common(1)[0][0])
print(prediction, len(prediction))

#create test csv
def pad4(i):
    return "0"*(4-len(str(i)))+str(i)
df = pd.DataFrame()
df["Id"] = [pad4(i) for i in range(len(test_set))]
df["Category"] = prediction
df.to_csv("submission_vote.csv",index = False)
# Out:
# ['5', '1', '0', '3', '9', '10', '3', '6', '1', '3', '3', '1', '8', '6', '3', '3', '3', '3', '9', '9', '2', '9', '4', '6', '2', '1', '4', '2', '3', '6', '1', '4', '0', '1', '8', '10', '7', '10', '10', '7', '4', '1', '1', '8', '9', '6', '3', '10', '1', '0', '3', '6', '2', '10', '10', '10', '5', '10', '6', '10', '4', '4', '1', '8', '2', '3', '7', '3', '8', '1', '1', '9', '6', '10', '7', '1', '3', '2', '1', '8', '9', '6', '3', '10', '0', '10', '0', '1', '1', '9', '10', '7', '9', '9', '7', '7', '6', '7', '4', '5', '5', '0', '3', '10', '9', '7', '7', '2', '5', '1', '3', '1', '9', '1', '1', '6', '3', '8', '0', '7', '8', '9', '6', '2', '3', '7', '10', '3', '1', '1', '1', '8', '6', '7', '3', '3', '10', '1', '2', '10', '8', '9', '10', '0', '7', '3', '3', '9', '10', '9', '3', '3', '10', '3', '7', '7', '3', '0', '1', '0', '3', '0', '3', '6', '1', '3', '8', '2', '3', '9', '1', '1', '7', '1', '8', '1', '1', '0', '3', '5', '1', '10', '7', '6', '1', '2', '10', '0', '9', '9', '7', '10', '10', '5', '8', '3', '1', '7', '6', '0', '1', '9', '6', '9', '3', '10', '9', '2', '8', '6', '0', '3', '1', '6', '9', '5', '8', '10', '10', '3', '3', '7', '7', '3', '1', '3', '8', '7', '0', '9', '1', '7', '0', '3', '3', '9', '3', '0', '1', '5', '9', '7', '1', '1', '9', '2', '1', '7', '3', '3', '8', '1', '1', '9', '6', '0', '0', '7', '8', '6', '8', '1', '8', '4', '6', '0', '1', '0', '5', '10', '7', '10', '5', '3', '7', '9', '1', '8', '1', '10', '3', '10', '3', '1', '1', '1', '9', '8', '1', '7', '10', '5', '8', '0', '7', '7', '1', '1', '0', '8', '1', '3', '1', '1', '1', '10', '1', '7', '7', '1', '1', '4', '6', '9', '10', '1', '0', '5', '1', '0', '6', '0', '2', '3', '8', '7', '1', '3', '3', '3', '7', '10', '7', '6', '10', '1', '10', '1', '9', '0', '9', '3', '8', '10', '3', '6', '9', '1', '7', '4', '2', '7', '10', '7', '4', '2', '5', '0', '1', '8', '10', '6', '7', '1', '3', '4', '1', '6', '6', '9', '10', '3', '1', '7', '0', '7', '0', '3', '8', '0', '8', '1', '7', '8', '7', '3', '9', '9', '10', '9', '3', '0', '1', '10', '8', '3', '5', '10', '7', '6', '3', '1', '1', '6', '10', '7', '3', '4', '1', '1', '7', '7', '3', '5', '3', '1', '1', '7', '3', '7', '5', '9', '1', '9', '10', '6', '5', '1', '8', '7', '10', '3', '8', '3', '1', '1', '6', '4', '6', '8', '2', '10', '1', '1', '6', '8', '5', '8', '9', '0', '10', '7', '1', '0', '3', '3', '9', '10', '10', '8', '1', '9', '1', '0', '3', '4', '3', '10', '0', '6', '5', '0', '1', '8', '0', '8', '2', '8', '3', '7', '7', '4', '5', '9', '0', '7', '6', '7', '7', '7', '1', '7', '1', '7', '10', '1', '7', '0', '2', '2', '1', '8', '10', '1', '1', '8', '0', '1', '9', '9', '9', '3', '3', '3', '0', '2', '6', '8', '6', '10', '6', '9', '7', '8', '10', '10', '3', '1', '7', '6', '2', '7', '10', '7', '6', '3', '6', '6', '6', '3', '3', '8', '9', '6', '8', '7', '0', '0', '8', '3', '10', '7', '2', '7', '1', '9', '1', '1', '5', '10', '5', '10', '6', '0', '7', '7', '1', '9', '10', '5', '1', '10', '6', '3', '1', '3', '10', '1', '10', '1', '3', '3', '10', '4', '5', '7', '0', '2', '1', '6', '5', '1', '3', '10', '0', '3', '10', '7', '10', '4', '6', '3', '7', '5', '10', '7', '3', '1', '10', '3', '3', '9', '7', '3', '5', '6', '2', '4', '6', '1', '9', '10', '1', '1', '9', '0', '9', '1', '6', '1', '0', '9', '6', '7', '7', '1', '1', '3', '7', '6', '8', '0', '3', '9', '1', '2', '3', '6', '5', '4', '1', '8', '10', '8', '10', '0', '9', '2', '1', '10', '1', '3', '9', '2', '0', '3', '3', '8', '7', '8', '6', '1', '3', '2', '1', '9', '0', '3', '6', '0', '1', '3', '6', '10', '5', '5', '1', '9', '6', '8', '6', '0', '10', '7', '9', '8', '5', '1', '7', '0', '2', '8', '1', '3', '7', '6', '4', '1', '7', '10', '1', '3', '6', '4', '9', '6', '3', '3', '5', '6', '8', '5', '2', '3', '2', '10', '3', '0', '4', '2', '6', '7', '3', '2', '2', '2', '0', '4', '7', '9', '1', '7', '9', '0', '10', '3', '7', '0', '3', '10', '2', '1', '7', '1', '2', '7', '5', '7', '1', '3', '7', '7', '3', '5', '0', '9', '6', '6', '3', '3', '9', '9', '6', '3', '9', '3', '5', '9', '1', '3', '1', '7', '9', '7 ...
